# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
# Unified Helper Functions (unchanged)
def compute_rsi(data, periods=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=periods).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=periods).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

# %%
def trend_strength(df_segment, window=20):
    df = df_segment.tail(window)
    x = np.arange(len(df))
    slope, _, r_value, _, _ = linregress(x, df["Close"].values)
    macd_avg = df["MACD"].mean()
    if slope > 0 and macd_avg > 0:
        return "bullish", abs(slope), r_value**2
    elif slope < 0 and macd_avg < 0:
        return "bearish", abs(slope), r_value**2
    return "neutral", 0, 0

# %%
def find_all_extrema(data):
    local_maxima = []
    local_minima = []
    if isinstance(data, pd.Series):
        index = data.index
        values = data.values
    else:
        index = range(len(data))
        values = data
    for i in range(1, len(values) - 1):
        if values[i] > values[i-1] and values[i] > values[i+1]:
            local_maxima.append((index[i], values[i]))
        elif values[i] < values[i-1] and values[i] < values[i+1]:
            local_minima.append((index[i], values[i]))
    global_max_idx = np.argmax(values)
    global_min_idx = np.argmin(values)
    local_maxima.append((index[global_max_idx], values[global_max_idx]))
    local_minima.append((index[global_min_idx], values[global_min_idx]))
    local_maxima = sorted(set(local_maxima), key=lambda x: x[0])
    local_minima = sorted(set(local_minima), key=lambda x: x[0])
    return local_maxima, local_minima

# %%
def get_top_extrema(local_maxima, local_minima, top_n=5):
    top_maxima = sorted(local_maxima, key=lambda x: x[1], reverse=True)[:top_n]
    bottom_minima = sorted(local_minima, key=lambda x: x[1])[:top_n]
    return top_maxima, bottom_minima

# %%
# Updated Pattern Detection Functions with Relaxed Conditions
def detect_head_and_shoulders(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(top_maxima) < 3:
        print(f"Head and Shoulders - Insufficient maxima: {len(top_maxima)} < 3")
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    last_three = top_maxima[-3:]
    ls, head, rs = last_three[0], last_three[1], last_three[2]
    shoulder_diff = abs(ls[1] - rs[1]) / ls[1]
    if not (head[1] > ls[1] and head[1] > rs[1] and shoulder_diff < 0.30):  # Relaxed from 0.25
        print("Failed shoulder-head condition")
        return None, None, 0

    neckline_minima = [m for m in local_minima if ls[0] < m[0] < rs[0]]
    if len(neckline_minima) < 2:
        print(f"Head and Shoulders - Insufficient neckline minima: {len(neckline_minima)} < 2")
        return None, None, 0

    neckline_slope, _, r_value, _, _ = linregress(
        [m[0].to_pydatetime().timestamp() for m in neckline_minima],
        [m[1] for m in neckline_minima]
    )
    if abs(neckline_slope) > 0.0024 or r_value**2 < 0.15:  # Relaxed from 0.003 and 0.2
        print(f"Neckline too steep or weak fit: Slope {abs(neckline_slope):.6f} > 0.0024 or R² {r_value**2:.4f} < 0.15")
        return None, None, 0

    neckline = np.mean([m[1] for m in neckline_minima])
    breakdown_threshold = 0.98 if prev_label == "Head and Shoulders" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 0.97  # Relaxed from 0.99 and 0.98
    if df_segment["Close"].iloc[-1] < neckline * breakdown_threshold:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bearish" and df_segment["RSI"].iloc[-1] < 85:  # Relaxed from 80
            confidence = min(0.9 + strength * 2, 1.0) * r_value**2 * 0.9
            return "Head and Shoulders", (ls[0], rs[0]), confidence
    return None, None, 0

# %%
def detect_symmetrical_triangle(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(top_maxima) < 2 or len(bottom_minima) < 2:
        print(f"Symmetrical Triangle - Insufficient extrema: Maxima {len(top_maxima)} < 2 or Minima {len(bottom_minima)} < 2")
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    bottom_minima.sort(key=lambda x: x[0])
    max_values = [m[1] for m in top_maxima]
    min_values = [m[1] for m in bottom_minima]
    max_slope, _, max_r, _, _ = linregress(
        [m[0].to_pydatetime().timestamp() for m in top_maxima], max_values
    )
    min_slope, _, min_r, _, _ = linregress(
        [m[0].to_pydatetime().timestamp() for m in bottom_minima], min_values
    )
    if max_r**2 < 0.2 or min_r**2 < 0.2:  # Relaxed from 0.3
        print(f"Trendlines too weak: max_r² {max_r**2:.4f} < 0.2 or min_r² {min_r**2:.4f} < 0.2")
        return None, None, 0

    breakout_val = abs(df_segment["Close"].iloc[-1] - df_segment["Close"].iloc[-3]) / df_segment["Close"].iloc[-3]
    if breakout_val > 0.004:  # Relaxed from 0.005
        trend, strength, r2 = trend_strength(df_segment)
        if trend != "neutral":
            confidence = min(0.8 + strength * 2, 1.0) * min(max_r**2, min_r**2) * 0.8
            return "Symmetrical Triangle", (top_maxima[0][0], df_segment.index[-1]), confidence
    return None, None, 0

# %%
def detect_cup_and_handle(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(bottom_minima) < 2 or len(top_maxima) < 1:
        print(f"Cup and Handle - Insufficient extrema: Minima {len(bottom_minima)} < 2 or Maxima {len(top_maxima)} < 1")
        return None, None, 0

    bottom_minima.sort(key=lambda x: x[0])
    cup_min1, cup_min2 = bottom_minima[-2:]
    if (cup_min2[0] - cup_min1[0]).days < 1.5:  # Unchanged from previous relaxation
        print(f"Cup time too short: {(cup_min2[0] - cup_min1[0]).days} < 1.5 days")
        return None, None, 0

    cup_diff = abs(cup_min1[1] - cup_min2[1]) / cup_min1[1]
    if cup_diff > 0.6:  # Relaxed from 0.5
        print(f"Cup difference too large: {cup_diff:.4f} > 0.6")
        return None, None, 0

    mid_maxima = [m[1] for m in local_maxima if cup_min1[0] < m[0] < cup_min2[0]]
    if not mid_maxima:
        print("No mid maxima for cup")
        return None, None, 0

    cup_neckline = max(mid_maxima)
    handle_max = max([(m[0], m[1]) for m in top_maxima if m[0] > cup_min2[0]], default=None)
    if not handle_max or (handle_max[0] - cup_min2[0]).days < 10 or handle_max[1] > cup_neckline * 1.20:  # Changed from < 1 to < 5
        print(f"Handle max invalid: Exists: {bool(handle_max)}, Days: {(handle_max[0] - cup_min2[0]).days if handle_max else 'N/A'} < 5, Value: {handle_max[1] if handle_max else 'N/A'} > {cup_neckline * 1.20:.2f}")
        return None, None, 0

    post_handle = df_segment["Close"].loc[handle_max[0]:].head(3)
    if len(post_handle) < 2:  # Unchanged from previous relaxation
        print(f"Insufficient post-handle data: {len(post_handle)} < 2")
        return None, None, 0

    post_handle_changes = post_handle.pct_change().dropna()
    strict_downtrend = post_handle_changes.mean() < 0.001  # Unchanged from previous relaxation
    if strict_downtrend:
        breakout_threshold = 1.003  # Relaxed from 1.004
        print(f"Close: {df_segment['Close'].iloc[-1]:.2f}, Neckline: {cup_neckline:.2f}, Threshold: {cup_neckline * breakout_threshold:.2f}")
        if df_segment["Close"].iloc[-1] > cup_neckline * breakout_threshold:
            trend, strength, r2 = trend_strength(df_segment)
            print(f"Trend: {trend}, RSI: {df_segment['RSI'].iloc[-1]:.2f}")
            if trend == "bullish" and df_segment["RSI"].iloc[-1] > 35:  # Unchanged from previous relaxation
                confidence = max(0.1, min(0.8 + strength * 2, 1.0) * r2 * 0.8)  # Added confidence floor
                print(f"Detected Cup and Handle with confidence {confidence:.4f}")
                return "Cup and Handle", (cup_min1[0], df_segment.index[-1]), confidence
            else:
                print(f"Trend not bullish or RSI too low: Trend {trend}, RSI {df_segment['RSI'].iloc[-1]:.2f} <= 35")
        else:
            print("Breakout not confirmed")
    else:
        print("Handle not in strict downtrend")
    return None, None, 0

# %%
def detect_ascending_triangle(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(top_maxima) < 2 or len(bottom_minima) < 2:
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    bottom_minima.sort(key=lambda x: x[0])
    max_values = [m[1] for m in top_maxima]
    max_mean = np.mean(max_values)
    max_std = np.std(max_values)
    if max_std / max_mean >= 0.12:  # Relaxed from 0.10
        return None, None, 0

    min_values = [m[1] for m in bottom_minima]
    min_slope, _, r_value, _, _ = linregress(range(len(min_values)), min_values)
    if min_slope <= 0.0008 or r_value**2 <= 0.2:  # Relaxed from 0.001 and 0.3
        return None, None, 0

    highest_max = max(max_values)
    breakout = df_segment["Close"].iloc[-1] > highest_max * 0.75 and df_segment["Close"].iloc[-1] < highest_max * 1.25  # Relaxed from 0.8 and 1.2
    if breakout:
        trend, strength, _ = trend_strength(df_segment)
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 25:  # Relaxed from 30
            confidence = min(0.9 + strength * 5, 1.0) * r_value**2 * 0.8
            return "Ascending Triangle", (top_maxima[0][0], df_segment.index[-1]), confidence
    return None, None, 0

# %%
def detect_descending_triangle(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(top_maxima) < 2 or len(bottom_minima) < 2:
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    bottom_minima.sort(key=lambda x: x[0])
    max_values = [m[1] for m in top_maxima]
    max_slope, _, r_value, _, _ = linregress(range(len(max_values)), max_values)
    if max_slope >= -0.0008 or r_value**2 <= 0.2:  # Relaxed from -0.001 and 0.3
        return None, None, 0

    min_values = [m[1] for m in bottom_minima]
    min_mean = np.mean(min_values)
    min_std = np.std(min_values)
    if min_std / min_mean >= 0.12:  # Relaxed from 0.10
        return None, None, 0

    lowest_min = min(min_values)
    breakdown = df_segment["Close"].iloc[-1] < lowest_min * 1.25 and df_segment["Close"].iloc[-1] > lowest_min * 0.75  # Relaxed from 1.2 and 0.8
    if breakdown:
        trend, strength, _ = trend_strength(df_segment)
        if trend == "bearish" and df_segment["RSI"].iloc[-1] < 75:  # Relaxed from 70
            confidence = min(0.9 + strength * 5, 1.0) * r_value**2 * 0.8
            return "Descending Triangle", (top_maxima[0][0], df_segment.index[-1]), confidence
    return None, None, 0

# %%
def detect_inverse_head_and_shoulders(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(bottom_minima) < 3:
        return None, None, 0

    bottom_minima.sort(key=lambda x: x[0])
    last_three = bottom_minima[-3:]
    ls, head, rs = last_three[0], last_three[1], last_three[2]
    shoulder_diff = abs(ls[1] - rs[1]) / ls[1]
    if not (head[1] < ls[1] * 0.97 and head[1] < rs[1] * 0.97 and shoulder_diff < 0.20):  # Relaxed from 0.95 and 0.15
        return None, None, 0

    neckline_maxima = [m for m in local_maxima if ls[0] < m[0] < rs[0]]
    if len(neckline_maxima) < 2:
        return None, None, 0

    neckline_slope, _, r_value, _, _ = linregress(
        [m[0].to_pydatetime().timestamp() for m in neckline_maxima], [m[1] for m in neckline_maxima]
    )
    if abs(neckline_slope) > 0.0016 or r_value**2 < 0.2:  # Relaxed from 0.002 and 0.3
        return None, None, 0

    neckline = np.mean([m[1] for m in neckline_maxima])
    breakout_threshold = 1.04 if prev_label == "Inverse Head and Shoulders" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 1.01  # Relaxed from 1.05 and 1.02
    if df_segment["Close"].iloc[-1] > neckline * breakout_threshold:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 20:  # Relaxed from 25
            confidence = min(0.9 + strength * 2, 1.0) * r_value**2 * 0.9
            return "Inverse Head and Shoulders", (ls[0], rs[0]), confidence
    return None, None, 0

# %%
def detect_falling_wedge(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    print(f"Falling Wedge - Maxima count: {len(top_maxima)}, Minima count: {len(bottom_minima)}")
    if len(top_maxima) < 2 or len(bottom_minima) < 2:
        print(f"Insufficient extrema: Maxima {len(top_maxima)} < 2 or Minima {len(bottom_minima)} < 2")
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    bottom_minima.sort(key=lambda x: x[0])
    max_values = [m[1] for m in top_maxima]
    min_values = [m[1] for m in bottom_minima]
    max_slope, _, max_r, _, _ = linregress(range(len(max_values)), max_values)
    min_slope, _, min_r, _, _ = linregress(range(len(min_values)), min_values)
    print(f"Max slope: {max_slope:.6f}, Min slope: {min_slope:.6f}, max_r²: {max_r**2:.4f}, min_r²: {min_r**2:.4f}")
    if max_slope > -0.0012 or min_slope > -0.0012 or max_r**2 <= 0.25 or min_r**2 <= 0.25:  # Changed >= to > for correct downward slope
        print(f"Slopes not steep enough or weak fit: Max slope {max_slope:.6f} > -0.0012, Min slope {min_slope:.6f} > -0.0012, max_r² {max_r**2:.4f} <= 0.25, min_r² {min_r**2:.4f} <= 0.25")
        return None, None, 0

    slope_ratio = abs(max_slope) / abs(min_slope)
    if slope_ratio >= 4.0:  # Relaxed from 3.5
        print(f"Slope ratio too large: {slope_ratio:.4f} >= 4.0")
        return None, None, 0

    highest_max = max(max_values)
    breakout = df_segment["Close"].iloc[-1] > highest_max * 0.75 and df_segment["Close"].iloc[-1] < highest_max * 1.25  # Relaxed from 0.80-1.20
    print(f"Breakout check: {highest_max * 0.75:.2f} < Close {df_segment['Close'].iloc[-1]:.2f} < {highest_max * 1.25:.2f}")
    if breakout:
        trend, strength, _ = trend_strength(df_segment)
        print(f"Trend: {trend}, RSI: {df_segment['RSI'].iloc[-1]:.2f}")
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 30:  # Unchanged from previous relaxation
            confidence = max(0.1, min(0.9 + strength * 5, 1.0) * min(max_r**2, min_r**2) * 0.8)  # Added confidence floor
            print(f"Detected Falling Wedge with confidence {confidence:.4f}")
            return "Falling Wedge", (top_maxima[0][0], df_segment.index[-1]), confidence
        else:
            print(f"Trend not bullish or RSI too low: Trend {trend}, RSI {df_segment['RSI'].iloc[-1]:.2f} <= 30")
    else:
        print("No breakout")
    return None, None, 0

# %%
def detect_rounding_bottom(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(bottom_minima) < 1 or (df_segment.index[-1] - bottom_minima[0][0]).days < 12:  # Relaxed from 15
        return None, None, 0

    bottom = bottom_minima[0]
    initial_price = df_segment["Close"].iloc[0]
    if initial_price <= bottom[1] * 1.10:  # Relaxed from 1.05
        return None, None, 0

    left = df_segment["Close"].loc[:bottom[0]]
    right = df_segment["Close"].loc[bottom[0]:]
    if len(left) < 8 or len(right) < 8:  # Relaxed from 10
        return None, None, 0

    left_slope, _, left_r, _, _ = linregress(range(len(left.tail(8))), left.tail(8).values)
    right_slope, _, right_r, _, _ = linregress(range(len(right.head(8))), right.head(8).values)
    if left_slope <= -0.00024 or right_slope <= 0.00024 or left_r**2 < 0.15 or right_r**2 < 0.15:  # Relaxed from -0.0003, 0.0003, and 0.20
        return None, None, 0

    breakout_threshold = 1.04 if prev_label == "Rounding Bottom" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 1.008  # Relaxed from 1.05 and 1.01
    if df_segment["Close"].iloc[-1] > initial_price * breakout_threshold:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 20:  # Relaxed from 25
            confidence = min(0.9 + strength * 2, 1.0) * min(left_r**2, right_r**2) * 0.9
            return "Rounding Bottom", (df_segment.index[0], df_segment.index[-1]), confidence
    return None, None, 0

# %%
def detect_triple_bottom_reversal(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(bottom_minima) < 3:
        return None, None, 0

    bottom_minima.sort(key=lambda x: x[0])
    last_three = bottom_minima[-3:]
    min1, min2, min3 = last_three[0], last_three[1], last_three[2]
    if (min3[0] - min1[0]).days < 8 or (min2[0] - min1[0]).days < 2:  # Relaxed from 10 and 3
        return None, None, 0

    avg_min = (min1[1] + min2[1] + min3[1]) / 3
    diff_min = max(abs(min1[1] - min2[1]), abs(min2[1] - min3[1])) / avg_min
    if diff_min > 0.20:  # Relaxed from 0.15
        return None, None, 0

    mid_maxima = [m for m in local_maxima if min1[0] < m[0] < min3[0]]
    if len(mid_maxima) < 1:  # Relaxed from 2
        return None, None, 0

    max_mean = np.mean([m[1] for m in mid_maxima])
    max_std = np.std([m[1] for m in mid_maxima])
    if max_std / max_mean > 0.30:  # Relaxed from 0.25
        return None, None, 0

    neckline = max([m[1] for m in mid_maxima])
    breakout_threshold = 1.04 if prev_label == "Triple Bottom Reversal" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 1.008  # Relaxed from 1.05 and 1.01
    if df_segment["Close"].iloc[-1] > neckline * breakout_threshold:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 20:  # Relaxed from 25
            confidence = min(0.9 + strength * 2, 1.0) * r2 * 0.9
            return "Triple Bottom Reversal", (min1[0], min3[0]), confidence
    return None, None, 0

# %%
def detect_double_top(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(top_maxima) < 2:
        return None, None, 0

    top_maxima.sort(key=lambda x: x[0])
    last_two = top_maxima[-2:]
    max1, max2 = last_two[0], last_two[1]
    if (max2[0] - max1[0]).days < 4:  # Relaxed from 5
        return None, None, 0

    initial_price = df_segment["Close"].iloc[0]
    if initial_price >= max1[1] * 0.95 or initial_price >= max2[1] * 0.95:  # Relaxed from 0.97
        return None, None, 0

    diff = abs(max1[1] - max2[1]) / ((max1[1] + max2[1]) / 2)
    if diff > 0.20:  # Relaxed from 0.15
        return None, None, 0

    mid_minima = [m[1] for m in local_minima if max1[0] < m[0] < max2[0]]
    if not mid_minima:
        return None, None, 0

    neckline = min(mid_minima)
    if not (initial_price * 0.75 < neckline < initial_price * 1.25):  # Relaxed from 0.8 and 1.2
        return None, None, 0

    breakdown_threshold = 0.96 if prev_label == "Double Top" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 0.97  # Relaxed from 0.95 and 0.98
    breakdown = df_segment["Close"].loc[max2[0]:].min() < neckline * breakdown_threshold
    if breakdown:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bearish" and df_segment["RSI"].iloc[-1] < 80:  # Relaxed from 75
            confidence = min(0.9 + strength * 2, 1.0) * r2 * 0.9
            return "Double Top", (max1[0], max2[0]), confidence
    return None, None, 0

# %%
def detect_double_bottom(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    top_maxima, bottom_minima = get_top_extrema(local_maxima, local_minima)
    if len(bottom_minima) < 2:
        return None, None, 0

    bottom_minima.sort(key=lambda x: x[0])
    last_two = bottom_minima[-2:]
    min1, min2 = last_two[0], last_two[1]
    if (min2[0] - min1[0]).days < 4:  # Relaxed from 5
        return None, None, 0

    initial_price = df_segment["Close"].iloc[0]
    if initial_price <= min1[1] * 1.05 or initial_price <= min2[1] * 1.05:  # Relaxed from 1.03
        return None, None, 0

    diff = abs(min1[1] - min2[1]) / ((min1[1] + min2[1]) / 2)
    if diff > 0.20:  # Relaxed from 0.15
        return None, None, 0

    mid_maxima = [m[1] for m in local_maxima if min1[0] < m[0] < min2[0]]
    if not mid_maxima:
        return None, None, 0

    neckline = max(mid_maxima)
    if not (initial_price * 0.75 < neckline < initial_price * 1.25):  # Relaxed from 0.8 and 1.2
        return None, None, 0

    breakout_threshold = 1.04 if prev_label == "Double Bottom" and prev_bb and df_segment.index[0] > prev_bb["x_max"] else 1.01  # Relaxed from 1.05 and 1.02
    breakout = df_segment["Close"].loc[min2[0]:].max() > neckline * breakout_threshold
    if breakout:
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bullish" and df_segment["RSI"].iloc[-1] > 20:  # Relaxed from 25
            confidence = min(0.9 + strength * 2, 1.0) * r2 * 0.9
            return "Double Bottom", (min1[0], min2[0]), confidence
    return None, None, 0

# %%
def detect_flag_and_pole(df_segment, prev_label=None, prev_bb=None):
    local_maxima, local_minima = find_all_extrema(df_segment["Close"])
    if len(local_maxima) < 1 or len(local_minima) < 1:
        return None, None, 0

    pole_max = sorted(local_maxima, key=lambda x: x[0])[0]
    initial_price = df_segment["Close"].iloc[0]
    if initial_price >= pole_max[1] * 0.95:  # Relaxed from 0.97
        return None, None, 0

    pole_change = (pole_max[1] - initial_price) / initial_price
    if pole_change < 0.025 or (pole_max[0] - df_segment.index[0]).days < 4:  # Relaxed from 0.03 and 5
        return None, None, 0

    flag_min = next((m for m in local_minima if m[0] > pole_max[0]), None)
    if not flag_min or (flag_min[0] - pole_max[0]).days < 2:  # Relaxed from 3
        return None, None, 0

    flag_range = df_segment["Close"].loc[pole_max[0]:flag_min[0]]
    flag_volatility = flag_range.std() / flag_range.mean()
    if flag_volatility > 0.04:  # Relaxed from 0.03
        return None, None, 0

    if df_segment["Close"].iloc[-1] > pole_max[1] * 1.008:  # Relaxed from 1.01
        trend, strength, r2 = trend_strength(df_segment)
        if trend == "bullish":
            confidence = min(0.9 + strength * 2, 1.0) * r2 * 0.9
            return "Flag and Pole", (df_segment.index[0], df_segment.index[-1]), confidence
    return None, None, 0

# %%
# Main Processing Function (updated)
def process_patterns(csv_path):
    df = pd.read_csv(csv_path)
    required_cols = ["Date", "Open", "High", "Low", "Close"]
    if not all(col in df.columns for col in required_cols):
        raise ValueError("CSV must contain 'Date', 'Open', 'High', 'Low', 'Close' columns.")

    df["Date"] = pd.to_datetime(df["Date"])
    df.set_index("Date", inplace=True)
    df.sort_index(inplace=True)

    df["MACD"] = df["Close"].ewm(span=12, adjust=False).mean() - df["Close"].ewm(span=26, adjust=False).mean()
    df["Signal"] = df["MACD"].ewm(span=9, adjust=False).mean()
    df["RSI"] = compute_rsi(df["Close"])

    num_days = 90
    step = 90
    results = []
    prev_label = None
    prev_bb = None
    MIN_CONFIDENCE = 0.02 # Relaxed from 0.005

    pattern_functions = [
        detect_head_and_shoulders, detect_symmetrical_triangle, detect_cup_and_handle,
        detect_ascending_triangle, detect_descending_triangle, detect_inverse_head_and_shoulders,
        detect_falling_wedge, detect_rounding_bottom, detect_triple_bottom_reversal,
        detect_double_top, detect_double_bottom, detect_flag_and_pole
    ]

    for start_idx in range(0, len(df) - num_days + 1, step):
        end_idx = start_idx + num_days
        df_segment = df.iloc[start_idx:end_idx].dropna(subset=["Close", "RSI", "MACD"])
        label = f"{start_idx + 1}-{end_idx}"
        print(f"\nProcessing segment: {label}")

        best_pattern = None
        best_date_range = None
        best_confidence = 0

        for pattern_func in pattern_functions:
            pattern_name, date_range, confidence = pattern_func(df_segment, prev_label, prev_bb)
            if pattern_name and confidence > best_confidence:
                print(f"Detected {pattern_name} with confidence {confidence:.4f}")
                best_pattern = pattern_name
                best_date_range = date_range
                best_confidence = confidence

        if best_confidence < MIN_CONFIDENCE:
            results.append({"label": label, "pattern": "No Pattern Detected", "confidence": 0.0, "bounding_box": None})
            prev_label = None
            prev_bb = None
        else:
            start_date, end_date = best_date_range
            segment = df_segment.loc[start_date:end_date]
            x_min, x_max = segment.index[0], segment.index[-1]
            y_min, y_max = segment["Low"].min(), segment["High"].max()
            bounding_box = {"x_min": x_min, "y_min": y_min, "x_max": x_max, "y_max": y_max}
            results.append({
                "label": label,
                "pattern": best_pattern,
                "confidence": best_confidence,
                "bounding_box": bounding_box
            })
            prev_label = best_pattern
            prev_bb = bounding_box

    detected = sum(1 for r in results if r["pattern"] != "No Pattern Detected")
    print(f"Detected patterns in {detected}/{len(results)} segments ({detected/len(results)*100:.1f}%)")

    for result in results:
        print(f"Period: {result['label']}")
        print(f"Pattern: {result['pattern']} (Confidence: {result['confidence']:.4f})")
        if result['bounding_box']:
            print(f"Bounding Box: x_min={result['bounding_box']['x_min']}, y_min={result['bounding_box']['y_min']}, "
                  f"x_max={result['bounding_box']['x_max']}, y_max={result['bounding_box']['y_max']}")
        print()

    return results

# Usage
if __name__ == "__main__":
    csv_path = "/content/drive/MyDrive/nifty 50/AXISBANK.csv"  # Update as needed
    results = process_patterns(csv_path)
# Out:
# Processing segment: 1-90
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4257
# Handle max invalid: Exists: True, Days: 4 < 5, Value: 39.7 > 38.82
# Detected Ascending Triangle with confidence 0.6952
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.965000, Min slope: 1.490000, max_r²: 0.7482, min_r²: 0.8690
# Slopes not steep enough or weak fit: Max slope -0.965000 > -0.0012, Min slope 1.490000 > -0.0012, max_r² 0.7482 <= 0.25, min_r² 0.8690 <= 0.25
#
# Processing segment: 91-180
# Failed shoulder-head condition
# Close: 36.95, Neckline: 34.45, Threshold: 34.55
# Trend: neutral, RSI: 41.21
# Trend not bullish or RSI too low: Trend neutral, RSI 41.21 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.400000, Min slope: 0.165000, max_r²: 0.3421, min_r²: 0.8377
# Slopes not steep enough or weak fit: Max slope -0.400000 > -0.0012, Min slope 0.165000 > -0.0012, max_r² 0.3421 <= 0.25, min_r² 0.8377 <= 0.25
#
# Processing segment: 181-270
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.3284 < 0.2 or min_r² 0.0577 < 0.2
# Handle max invalid: Exists: True, Days: 86 < 5, Value: 54.05 > 46.08
# Detected Inverse Head and Shoulders with confidence 0.8213
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.975000, Min slope: 0.125000, max_r²: 0.3700, min_r²: 0.0079
# Slopes not steep enough or weak fit: Max slope 0.975000 > -0.0012, Min slope 0.125000 > -0.0012, max_r² 0.3700 <= 0.25, min_r² 0.0079 <= 0.25
#
# Processing segment: 271-360
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.7805 < 0.2 or min_r² 0.1824 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 32.22
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.205000, Min slope: -0.435000, max_r²: 0.6842, min_r²: 0.2220
# Slopes not steep enough or weak fit: Max slope -1.205000 > -0.0012, Min slope -0.435000 > -0.0012, max_r² 0.6842 <= 0.25, min_r² 0.2220 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.1354
#
# Processing segment: 361-450
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.3023
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 29.10
# Detected Descending Triangle with confidence 0.6515
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.480000, Min slope: 0.340000, max_r²: 0.8144, min_r²: 0.4092
# Slopes not steep enough or weak fit: Max slope -1.480000 > -0.0012, Min slope 0.340000 > -0.0012, max_r² 0.8144 <= 0.25, min_r² 0.4092 <= 0.25
#
# Processing segment: 451-540
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.9461 < 0.2 or min_r² 0.0448 < 0.2
# Handle max invalid: Exists: True, Days: 54 < 5, Value: 44.55 > 31.56
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 3.610000, Min slope: 0.200000, max_r²: 0.9850, min_r²: 0.1726
# Slopes not steep enough or weak fit: Max slope 3.610000 > -0.0012, Min slope 0.200000 > -0.0012, max_r² 0.9850 <= 0.25, min_r² 0.1726 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.8151
#
# Processing segment: 541-630
# Failed shoulder-head condition
# Close: 39.50, Neckline: 36.15, Threshold: 36.26
# Trend: neutral, RSI: 34.88
# Trend not bullish or RSI too low: Trend neutral, RSI 34.88 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.180000, Min slope: -0.380000, max_r²: 0.4481, min_r²: 0.1579
# Slopes not steep enough or weak fit: Max slope 0.180000 > -0.0012, Min slope -0.380000 > -0.0012, max_r² 0.4481 <= 0.25, min_r² 0.1579 <= 0.25
#
# Processing segment: 631-720
# Failed shoulder-head condition
# Close: 36.40, Neckline: 35.05, Threshold: 35.16
# Trend: neutral, RSI: 55.74
# Trend not bullish or RSI too low: Trend neutral, RSI 55.74 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.290000, Min slope: 0.140000, max_r²: 0.8383, min_r²: 0.4327
# Slopes not steep enough or weak fit: Max slope -1.290000 > -0.0012, Min slope 0.140000 > -0.0012, max_r² 0.8383 <= 0.25, min_r² 0.4327 <= 0.25
#
# Processing segment: 721-810
# Neckline too steep or weak fit: Slope 0.000000 > 0.0024 or R² 0.0660 < 0.15
# Trendlines too weak: max_r² 0.0922 < 0.2 or min_r² 0.4830 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 47.88
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.080000, Min slope: 0.585000, max_r²: 0.0279, min_r²: 0.7600
# Slopes not steep enough or weak fit: Max slope -0.080000 > -0.0012, Min slope 0.585000 > -0.0012, max_r² 0.0279 <= 0.25, min_r² 0.7600 <= 0.25
#
# Processing segment: 811-900
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.7614
# Handle max invalid: Exists: True, Days: 104 < 5, Value: 82.3 > 52.86
# Detected Ascending Triangle with confidence 0.7662
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.130000, Min slope: 1.045000, max_r²: 0.9275, min_r²: 0.9577
# Slopes not steep enough or weak fit: Max slope 2.130000 > -0.0012, Min slope 1.045000 > -0.0012, max_r² 0.9275 <= 0.25, min_r² 0.9577 <= 0.25
#
# Processing segment: 901-990
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4518
# Handle max invalid: Exists: True, Days: 75 < 5, Value: 119.7 > 81.66
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 10.275000, Min slope: -1.290000, max_r²: 0.7183, min_r²: 0.5192
# Slopes not steep enough or weak fit: Max slope 10.275000 > -0.0012, Min slope -1.290000 > -0.0012, max_r² 0.7183 <= 0.25, min_r² 0.5192 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7725
#
# Processing segment: 991-1080
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2084
# Handle max invalid: Exists: True, Days: 23 < 5, Value: 164.5 > 158.82
# Detected Ascending Triangle with confidence 0.2098
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.005000, Min slope: 2.460000, max_r²: 0.4644, min_r²: 0.2623
# Slopes not steep enough or weak fit: Max slope -2.005000 > -0.0012, Min slope 2.460000 > -0.0012, max_r² 0.4644 <= 0.25, min_r² 0.2623 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.4738
#
# Processing segment: 1081-1170
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 135.00
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -4.280000, Min slope: 1.390000, max_r²: 0.8847, min_r²: 0.7934
# Slopes not steep enough or weak fit: Max slope -4.280000 > -0.0012, Min slope 1.390000 > -0.0012, max_r² 0.8847 <= 0.25, min_r² 0.7934 <= 0.25
#
# Processing segment: 1171-1260
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0432 < 0.2 or min_r² 0.8377 < 0.2
# Handle max invalid: Exists: True, Days: 96 < 5, Value: 190.2 > 154.62
# Detected Ascending Triangle with confidence 0.5638
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.240000, Min slope: 2.585000, max_r²: 0.0418, min_r²: 0.7048
# Slopes not steep enough or weak fit: Max slope -0.240000 > -0.0012, Min slope 2.585000 > -0.0012, max_r² 0.0418 <= 0.25, min_r² 0.7048 <= 0.25
#
# Processing segment: 1261-1350
# Failed shoulder-head condition
# Close: 221.45, Neckline: 206.05, Threshold: 206.67
# Trend: neutral, RSI: 32.78
# Trend not bullish or RSI too low: Trend neutral, RSI 32.78 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.260000, Min slope: 7.170000, max_r²: 0.1772, min_r²: 0.8625
# Slopes not steep enough or weak fit: Max slope -2.260000 > -0.0012, Min slope 7.170000 > -0.0012, max_r² 0.1772 <= 0.25, min_r² 0.8625 <= 0.25
#
# Processing segment: 1351-1440
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1888 < 0.2 or min_r² 0.5987 < 0.2
# Close: 273.30, Neckline: 239.75, Threshold: 240.47
# Trend: bullish, RSI: 68.01
# Detected Cup and Handle with confidence 0.7061
# Detected Cup and Handle with confidence 0.7061
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.910000, Min slope: 1.280000, max_r²: 0.3896, min_r²: 0.4166
# Slopes not steep enough or weak fit: Max slope 2.910000 > -0.0012, Min slope 1.280000 > -0.0012, max_r² 0.3896 <= 0.25, min_r² 0.4166 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7943
#
# Processing segment: 1441-1530
# Detected Symmetrical Triangle with confidence 0.3956
# Handle max invalid: Exists: True, Days: 82 < 5, Value: 337.05 > 286.86
# Detected Ascending Triangle with confidence 0.4187
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 10.505000, Min slope: 3.440000, max_r²: 0.5407, min_r²: 0.5234
# Slopes not steep enough or weak fit: Max slope 10.505000 > -0.0012, Min slope 3.440000 > -0.0012, max_r² 0.5407 <= 0.25, min_r² 0.5234 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5158
#
# Processing segment: 1531-1620
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0092 < 0.2 or min_r² 0.6558 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 312.84
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.025000, Min slope: -19.060000, max_r²: 0.0660, min_r²: 0.9833
# Slopes not steep enough or weak fit: Max slope 1.025000 > -0.0012, Min slope -19.060000 > -0.0012, max_r² 0.0660 <= 0.25, min_r² 0.9833 <= 0.25
# Detected Double Top with confidence 0.7144
#
# Processing segment: 1621-1710
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.8870 < 0.2 or min_r² 0.0065 < 0.2
# Handle max invalid: Exists: True, Days: 91 < 5, Value: 420.1 > 316.32
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 7.505000, Min slope: -0.255000, max_r²: 0.7634, min_r²: 0.0026
# Slopes not steep enough or weak fit: Max slope 7.505000 > -0.0012, Min slope -0.255000 > -0.0012, max_r² 0.7634 <= 0.25, min_r² 0.0026 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7645
#
# Processing segment: 1711-1800
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0345 < 0.2 or min_r² 0.8364 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 705.30
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.975000, Min slope: 11.825000, max_r²: 0.0287, min_r²: 0.9334
# Slopes not steep enough or weak fit: Max slope 1.975000 > -0.0012, Min slope 11.825000 > -0.0012, max_r² 0.0287 <= 0.25, min_r² 0.9334 <= 0.25
#
# Processing segment: 1801-1890
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4102
# Handle max invalid: Exists: True, Days: 77 < 5, Value: 644.8 > 599.22
# Detected Ascending Triangle with confidence 0.4363
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 5.965000, Min slope: 8.205000, max_r²: 0.9608, min_r²: 0.5454
# Slopes not steep enough or weak fit: Max slope 5.965000 > -0.0012, Min slope 8.205000 > -0.0012, max_r² 0.9608 <= 0.25, min_r² 0.5454 <= 0.25
#
# Processing segment: 1891-1980
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.5448
# Handle max invalid: Exists: True, Days: 88 < 5, Value: 996.4 > 725.58
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 28.100000, Min slope: -14.270000, max_r²: 0.9132, min_r²: 0.7982
# Slopes not steep enough or weak fit: Max slope 28.100000 > -0.0012, Min slope -14.270000 > -0.0012, max_r² 0.9132 <= 0.25, min_r² 0.7982 <= 0.25
#
# Processing segment: 1981-2070
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0390 < 0.2 or min_r² 0.5700 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 968.64
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -7.155000, Min slope: -18.425000, max_r²: 0.0291, min_r²: 0.4493
# Slopes not steep enough or weak fit: Max slope -7.155000 > -0.0012, Min slope -18.425000 > -0.0012, max_r² 0.0291 <= 0.25, min_r² 0.4493 <= 0.25
#
# Processing segment: 2071-2160
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1801 < 0.2 or min_r² 0.6753 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 815.10
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -8.635000, Min slope: 15.960000, max_r²: 0.2005, min_r²: 0.6777
# Slopes not steep enough or weak fit: Max slope -8.635000 > -0.0012, Min slope 15.960000 > -0.0012, max_r² 0.2005 <= 0.25, min_r² 0.6777 <= 0.25
#
# Processing segment: 2161-2250
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0003 < 0.2 or min_r² 0.8482 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 600.96
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.700000, Min slope: 26.475000, max_r²: 0.0285, min_r²: 0.8008
# Slopes not steep enough or weak fit: Max slope 1.700000 > -0.0012, Min slope 26.475000 > -0.0012, max_r² 0.0285 <= 0.25, min_r² 0.8008 <= 0.25
#
# Processing segment: 2251-2340
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.4508 < 0.2 or min_r² 0.0006 < 0.2
# Handle max invalid: Exists: True, Days: 59 < 5, Value: 778.4 > 429.60
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 46.165000, Min slope: -0.540000, max_r²: 0.8716, min_r²: 0.0011
# Slopes not steep enough or weak fit: Max slope 46.165000 > -0.0012, Min slope -0.540000 > -0.0012, max_r² 0.8716 <= 0.25, min_r² 0.0011 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7748
#
# Processing segment: 2341-2430
# Trendlines too weak: max_r² 0.0087 < 0.2 or min_r² 0.2437 < 0.2
# Handle max invalid: Exists: True, Days: 82 < 5, Value: 932.6 > 911.58
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.540000, Min slope: -2.715000, max_r²: 0.1496, min_r²: 0.1164
# Slopes not steep enough or weak fit: Max slope -3.540000 > -0.0012, Min slope -2.715000 > -0.0012, max_r² 0.1496 <= 0.25, min_r² 0.1164 <= 0.25
#
# Processing segment: 2431-2520
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1563 < 0.2 or min_r² 0.4398 < 0.2
# Close: 1025.70, Neckline: 941.75, Threshold: 944.58
# Trend: neutral, RSI: 42.74
# Trend not bullish or RSI too low: Trend neutral, RSI 42.74 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 5.595000, Min slope: 8.225000, max_r²: 0.1364, min_r²: 0.5555
# Slopes not steep enough or weak fit: Max slope 5.595000 > -0.0012, Min slope 8.225000 > -0.0012, max_r² 0.1364 <= 0.25, min_r² 0.5555 <= 0.25
#
# Processing segment: 2521-2610
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2972
# Close: 1215.00, Neckline: 1107.45, Threshold: 1110.77
# Trend: bullish, RSI: 47.84
# Detected Cup and Handle with confidence 0.2855
# Detected Ascending Triangle with confidence 0.6173
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -7.230000, Min slope: 21.205000, max_r²: 0.2157, min_r²: 0.7716
# Slopes not steep enough or weak fit: Max slope -7.230000 > -0.0012, Min slope 21.205000 > -0.0012, max_r² 0.2157 <= 0.25, min_r² 0.7716 <= 0.25
#
# Processing segment: 2611-2700
# Failed shoulder-head condition
# Handle max invalid: Exists: True, Days: 98 < 5, Value: 1588.75 > 1503.96
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 14.700000, Min slope: 5.140000, max_r²: 0.5178, min_r²: 0.5625
# Slopes not steep enough or weak fit: Max slope 14.700000 > -0.0012, Min slope 5.140000 > -0.0012, max_r² 0.5178 <= 0.25, min_r² 0.5625 <= 0.25
#
# Processing segment: 2701-2790
# Neckline too steep or weak fit: Slope 0.000007 > 0.0024 or R² 0.0439 < 0.15
# Trendlines too weak: max_r² 0.7998 < 0.2 or min_r² 0.0010 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1479.00
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -45.565000, Min slope: 0.165000, max_r²: 0.8871, min_r²: 0.0001
# Slopes not steep enough or weak fit: Max slope -45.565000 > -0.0012, Min slope 0.165000 > -0.0012, max_r² 0.8871 <= 0.25, min_r² 0.0001 <= 0.25
#
# Processing segment: 2791-2880
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4016
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1442.88
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 4.930000, Min slope: -7.405000, max_r²: 0.6060, min_r²: 0.6652
# Slopes not steep enough or weak fit: Max slope 4.930000 > -0.0012, Min slope -7.405000 > -0.0012, max_r² 0.6060 <= 0.25, min_r² 0.6652 <= 0.25
#
# Processing segment: 2881-2970
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.0002 < 0.2 or min_r² 0.6555 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1402.26
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.165000, Min slope: -27.630000, max_r²: 0.0060, min_r²: 0.6733
# Slopes not steep enough or weak fit: Max slope 2.165000 > -0.0012, Min slope -27.630000 > -0.0012, max_r² 0.0060 <= 0.25, min_r² 0.6733 <= 0.25
#
# Processing segment: 2971-3060
# Failed shoulder-head condition
# Handle max invalid: Exists: True, Days: 65 < 5, Value: 1179.35 > 1154.70
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -20.545000, Min slope: 36.635000, max_r²: 0.5485, min_r²: 0.8056
# Slopes not steep enough or weak fit: Max slope -20.545000 > -0.0012, Min slope 36.635000 > -0.0012, max_r² 0.5485 <= 0.25, min_r² 0.8056 <= 0.25
#
# Processing segment: 3061-3150
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.5468
# Handle not in strict downtrend
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -41.235000, Min slope: 5.005000, max_r²: 0.8839, min_r²: 0.5780
# Slopes not steep enough or weak fit: Max slope -41.235000 > -0.0012, Min slope 5.005000 > -0.0012, max_r² 0.8839 <= 0.25, min_r² 0.5780 <= 0.25
#
# Processing segment: 3151-3240
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4561
# Handle max invalid: Exists: True, Days: 95 < 5, Value: 1359.05 > 1147.20
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 31.130000, Min slope: -16.315000, max_r²: 0.7139, min_r²: 0.5874
# Slopes not steep enough or weak fit: Max slope 31.130000 > -0.0012, Min slope -16.315000 > -0.0012, max_r² 0.7139 <= 0.25, min_r² 0.5874 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5048
#
# Processing segment: 3241-3330
# Failed shoulder-head condition
# Close: 1474.80, Neckline: 1314.90, Threshold: 1318.84
# Trend: neutral, RSI: 81.49
# Trend not bullish or RSI too low: Trend neutral, RSI 81.49 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 5.555000, Min slope: -28.695000, max_r²: 0.1625, min_r²: 0.7729
# Slopes not steep enough or weak fit: Max slope 5.555000 > -0.0012, Min slope -28.695000 > -0.0012, max_r² 0.1625 <= 0.25, min_r² 0.7729 <= 0.25
#
# Processing segment: 3331-3420
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.3176
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1037.16
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -14.050000, Min slope: -64.010000, max_r²: 0.3281, min_r²: 0.9172
# Breakout check: 1151.44 < Close 998.30 < 1919.06
# No breakout
#
# Processing segment: 3421-3510
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0040 < 0.2 or min_r² 0.0011 < 0.2
# Close: 1163.20, Neckline: 1250.40, Threshold: 1254.15
# Breakout not confirmed
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.630000, Min slope: -2.440000, max_r²: 0.0153, min_r²: 0.0524
# Slopes not steep enough or weak fit: Max slope 0.630000 > -0.0012, Min slope -2.440000 > -0.0012, max_r² 0.0153 <= 0.25, min_r² 0.0524 <= 0.25
#
# Processing segment: 3511-3600
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.1706
# Handle max invalid: Exists: True, Days: 109 < 5, Value: 1900.85 > 1345.14
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 51.030000, Min slope: -3.035000, max_r²: 0.6220, min_r²: 0.2722
# Slopes not steep enough or weak fit: Max slope 51.030000 > -0.0012, Min slope -3.035000 > -0.0012, max_r² 0.6220 <= 0.25, min_r² 0.2722 <= 0.25
#
# Processing segment: 3601-3690
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.1806
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 455.94
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 12.250000, Min slope: 0.900000, max_r²: 0.3074, min_r²: 0.2355
# Slopes not steep enough or weak fit: Max slope 12.250000 > -0.0012, Min slope 0.900000 > -0.0012, max_r² 0.3074 <= 0.25, min_r² 0.2355 <= 0.25
#
# Processing segment: 3691-3780
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1905 < 0.2 or min_r² 0.9477 < 0.2
# Handle max invalid: Exists: True, Days: 85 < 5, Value: 581.1 > 577.38
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -5.560000, Min slope: 16.685000, max_r²: 0.2071, min_r²: 0.9248
# Slopes not steep enough or weak fit: Max slope -5.560000 > -0.0012, Min slope 16.685000 > -0.0012, max_r² 0.2071 <= 0.25, min_r² 0.9248 <= 0.25
#
# Processing segment: 3781-3870
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2161
# Close: 571.70, Neckline: 551.10, Threshold: 552.75
# Trend: bullish, RSI: 62.68
# Detected Cup and Handle with confidence 0.5428
# Detected Cup and Handle with confidence 0.5428
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -15.355000, Min slope: -1.480000, max_r²: 0.7735, min_r²: 0.0567
# Slopes not steep enough or weak fit: Max slope -15.355000 > -0.0012, Min slope -1.480000 > -0.0012, max_r² 0.7735 <= 0.25, min_r² 0.0567 <= 0.25
# Detected Double Bottom with confidence 0.6106
#
# Processing segment: 3871-3960
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 558.18
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -8.240000, Min slope: 1.065000, max_r²: 0.6059, min_r²: 0.0503
# Slopes not steep enough or weak fit: Max slope -8.240000 > -0.0012, Min slope 1.065000 > -0.0012, max_r² 0.6059 <= 0.25, min_r² 0.0503 <= 0.25
#
# Processing segment: 3961-4050
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.6935 < 0.2 or min_r² 0.0934 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 463.62
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.580000, Min slope: 0.275000, max_r²: 0.6686, min_r²: 0.0251
# Slopes not steep enough or weak fit: Max slope -3.580000 > -0.0012, Min slope 0.275000 > -0.0012, max_r² 0.6686 <= 0.25, min_r² 0.0251 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.6805
#
# Processing segment: 4051-4140
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0088 < 0.2 or min_r² 0.8172 < 0.2
# Handle max invalid: Exists: True, Days: 96 < 5, Value: 574.1 > 566.88
# Detected Ascending Triangle with confidence 0.4959
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.575000, Min slope: 11.670000, max_r²: 0.0077, min_r²: 0.6199
# Slopes not steep enough or weak fit: Max slope 0.575000 > -0.0012, Min slope 11.670000 > -0.0012, max_r² 0.0077 <= 0.25, min_r² 0.6199 <= 0.25
#
# Processing segment: 4141-4230
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 573.72
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -10.115000, Min slope: -6.795000, max_r²: 0.8314, min_r²: 0.9562
# Breakout check: 476.92 < Close 438.10 < 794.88
# No breakout
#
# Processing segment: 4231-4320
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.3312 < 0.2 or min_r² 0.1426 < 0.2
# Close: 511.20, Neckline: 488.50, Threshold: 489.97
# Trend: bullish, RSI: 54.08
# Detected Cup and Handle with confidence 0.1000
# Detected Cup and Handle with confidence 0.1000
# Detected Ascending Triangle with confidence 0.2117
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.010000, Min slope: 2.560000, max_r²: 0.4708, min_r²: 0.2646
# Slopes not steep enough or weak fit: Max slope -2.010000 > -0.0012, Min slope 2.560000 > -0.0012, max_r² 0.4708 <= 0.25, min_r² 0.2646 <= 0.25
#
# Processing segment: 4321-4410
# Trendlines too weak: max_r² 0.1259 < 0.2 or min_r² 0.0542 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 612.72
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.170000, Min slope: 0.010000, max_r²: 0.0247, min_r²: 0.0000
# Slopes not steep enough or weak fit: Max slope 1.170000 > -0.0012, Min slope 0.010000 > -0.0012, max_r² 0.0247 <= 0.25, min_r² 0.0000 <= 0.25
#
# Processing segment: 4411-4500
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.3757
# Handle max invalid: Exists: True, Days: 85 < 5, Value: 620.1 > 583.14
# Detected Inverse Head and Shoulders with confidence 0.9000
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 13.480000, Min slope: -9.175000, max_r²: 0.7696, min_r²: 0.3900
# Slopes not steep enough or weak fit: Max slope 13.480000 > -0.0012, Min slope -9.175000 > -0.0012, max_r² 0.7696 <= 0.25, min_r² 0.3900 <= 0.25
#
# Processing segment: 4501-4590
# Failed shoulder-head condition
# Close: 531.40, Neckline: 548.75, Threshold: 550.40
# Breakout not confirmed
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -12.765000, Min slope: -1.035000, max_r²: 0.6826, min_r²: 0.1991
# Slopes not steep enough or weak fit: Max slope -12.765000 > -0.0012, Min slope -1.035000 > -0.0012, max_r² 0.6826 <= 0.25, min_r² 0.1991 <= 0.25
#
# Processing segment: 4591-4680
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.0026 < 0.2 or min_r² 0.2580 < 0.2
# Handle max invalid: Exists: True, Days: 71 < 5, Value: 636.4 > 617.70
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.700000, Min slope: -1.390000, max_r²: 0.0111, min_r²: 0.2335
# Slopes not steep enough or weak fit: Max slope -0.700000 > -0.0012, Min slope -1.390000 > -0.0012, max_r² 0.0111 <= 0.25, min_r² 0.2335 <= 0.25
#
# Processing segment: 4681-4770
# Failed shoulder-head condition
# Handle not in strict downtrend
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -8.090000, Min slope: 11.885000, max_r²: 0.5526, min_r²: 0.5711
# Slopes not steep enough or weak fit: Max slope -8.090000 > -0.0012, Min slope 11.885000 > -0.0012, max_r² 0.5526 <= 0.25, min_r² 0.5711 <= 0.25
#
# Processing segment: 4771-4860
# Trendlines too weak: max_r² 0.2098 < 0.2 or min_r² 0.1511 < 0.2
# Close: 766.40, Neckline: 735.05, Threshold: 737.26
# Trend: bullish, RSI: 48.05
# Detected Cup and Handle with confidence 0.1000
# Detected Cup and Handle with confidence 0.1000
# Detected Ascending Triangle with confidence 0.3283
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.955000, Min slope: 4.950000, max_r²: 0.0919, min_r²: 0.4104
# Slopes not steep enough or weak fit: Max slope -0.955000 > -0.0012, Min slope 4.950000 > -0.0012, max_r² 0.0919 <= 0.25, min_r² 0.4104 <= 0.25
#
# Processing segment: 4861-4950
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.5844 < 0.2 or min_r² 0.0065 < 0.2
# Close: 752.25, Neckline: 725.50, Threshold: 727.68
# Trend: bullish, RSI: 55.04
# Detected Cup and Handle with confidence 0.1000
# Detected Cup and Handle with confidence 0.1000
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.125000, Min slope: 0.640000, max_r²: 0.0938, min_r²: 0.0193
# Slopes not steep enough or weak fit: Max slope -1.125000 > -0.0012, Min slope 0.640000 > -0.0012, max_r² 0.0938 <= 0.25, min_r² 0.0193 <= 0.25
#
# Processing segment: 4951-5040
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1342 < 0.2 or min_r² 0.6752 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 682.56
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.550000, Min slope: -98.110000, max_r²: 0.0356, min_r²: 0.7909
# Slopes not steep enough or weak fit: Max slope -0.550000 > -0.0012, Min slope -98.110000 > -0.0012, max_r² 0.0356 <= 0.25, min_r² 0.7909 <= 0.25
#
# Processing segment: 5041-5130
# Neckline too steep or weak fit: Slope 0.000001 > 0.0024 or R² 0.0247 < 0.15
# Trendlines too weak: max_r² 0.0929 < 0.2 or min_r² 0.1116 < 0.2
# Close: 435.85, Neckline: 430.25, Threshold: 431.54
# Trend: neutral, RSI: 52.11
# Trend not bullish or RSI too low: Trend neutral, RSI 52.11 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.190000, Min slope: 3.445000, max_r²: 0.1294, min_r²: 0.0678
# Slopes not steep enough or weak fit: Max slope -3.190000 > -0.0012, Min slope 3.445000 > -0.0012, max_r² 0.1294 <= 0.25, min_r² 0.0678 <= 0.25
#
# Processing segment: 5131-5220
# Trendlines too weak: max_r² 0.0423 < 0.2 or min_r² 0.4562 < 0.2
# Handle max invalid: Exists: True, Days: 75 < 5, Value: 615.9 > 527.10
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.625000, Min slope: -4.940000, max_r²: 0.1464, min_r²: 0.3306
# Slopes not steep enough or weak fit: Max slope -2.625000 > -0.0012, Min slope -4.940000 > -0.0012, max_r² 0.1464 <= 0.25, min_r² 0.3306 <= 0.25
# Detected patterns in 35/58 segments (60.3%)
# Period: 1-90
# Pattern: Ascending Triangle (Confidence: 0.6952)
# Bounding Box: x_min=2000-02-04 00:00:00, y_min=26.05, x_max=2000-05-15 00:00:00, y_max=46.5
#
# Period: 91-180
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 181-270
# Pattern: Inverse Head and Shoulders (Confidence: 0.8213)
# Bounding Box: x_min=2000-10-03 00:00:00, y_min=30.8, x_max=2000-10-31 00:00:00, y_max=39.0
#
# Period: 271-360
# Pattern: Triple Bottom Reversal (Confidence: 0.1354)
# Bounding Box: x_min=2001-03-23 00:00:00, y_min=22.95, x_max=2001-04-02 00:00:00, y_max=28.9
#
# Period: 361-450
# Pattern: Descending Triangle (Confidence: 0.6515)
# Bounding Box: x_min=2001-06-13 00:00:00, y_min=21.0, x_max=2001-10-17 00:00:00, y_max=38.4
#
# Period: 451-540
# Pattern: Triple Bottom Reversal (Confidence: 0.8151)
# Bounding Box: x_min=2001-12-24 00:00:00, y_min=25.0, x_max=2002-01-02 00:00:00, y_max=27.2
#
# Period: 541-630
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 631-720
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 721-810
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 811-900
# Pattern: Ascending Triangle (Confidence: 0.7662)
# Bounding Box: x_min=2003-07-14 00:00:00, y_min=68.1, x_max=2003-08-06 00:00:00, y_max=83.8
#
# Period: 901-990
# Pattern: Triple Bottom Reversal (Confidence: 0.7725)
# Bounding Box: x_min=2003-09-16 00:00:00, y_min=63.25, x_max=2003-09-25 00:00:00, y_max=70.0
#
# Period: 991-1080
# Pattern: Triple Bottom Reversal (Confidence: 0.4738)
# Bounding Box: x_min=2004-03-16 00:00:00, y_min=122.15, x_max=2004-03-24 00:00:00, y_max=138.6
#
# Period: 1081-1170
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2004-05-04 00:00:00, y_min=131.5, x_max=2004-05-13 00:00:00, y_max=158.0
#
# Period: 1171-1260
# Pattern: Ascending Triangle (Confidence: 0.5638)
# Bounding Box: x_min=2004-12-02 00:00:00, y_min=150.0, x_max=2005-01-05 00:00:00, y_max=209.4
#
# Period: 1261-1350
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1351-1440
# Pattern: Triple Bottom Reversal (Confidence: 0.7943)
# Bounding Box: x_min=2005-05-26 00:00:00, y_min=218.0, x_max=2005-06-06 00:00:00, y_max=242.0
#
# Period: 1441-1530
# Pattern: Triple Bottom Reversal (Confidence: 0.5158)
# Bounding Box: x_min=2005-11-01 00:00:00, y_min=230.1, x_max=2005-11-10 00:00:00, y_max=243.5
#
# Period: 1531-1620
# Pattern: Double Top (Confidence: 0.7144)
# Bounding Box: x_min=2006-05-03 00:00:00, y_min=355.0, x_max=2006-05-10 00:00:00, y_max=380.0
#
# Period: 1621-1710
# Pattern: Triple Bottom Reversal (Confidence: 0.7645)
# Bounding Box: x_min=2006-07-13 00:00:00, y_min=249.5, x_max=2006-07-21 00:00:00, y_max=286.0
#
# Period: 1711-1800
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1801-1890
# Pattern: Ascending Triangle (Confidence: 0.4363)
# Bounding Box: x_min=2007-06-20 00:00:00, y_min=575.0, x_max=2007-07-13 00:00:00, y_max=659.8
#
# Period: 1891-1980
# Pattern: Symmetrical Triangle (Confidence: 0.5448)
# Bounding Box: x_min=2007-10-16 00:00:00, y_min=709.4, x_max=2007-11-20 00:00:00, y_max=1025.0
#
# Period: 1981-2070
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2071-2160
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2161-2250
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2251-2340
# Pattern: Triple Bottom Reversal (Confidence: 0.7748)
# Bounding Box: x_min=2009-03-09 00:00:00, y_min=278.25, x_max=2009-03-20 00:00:00, y_max=362.95
#
# Period: 2341-2430
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2431-2520
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2521-2610
# Pattern: Ascending Triangle (Confidence: 0.6173)
# Bounding Box: x_min=2010-04-26 00:00:00, y_min=1147.15, x_max=2010-06-17 00:00:00, y_max=1320.0
#
# Period: 2611-2700
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2701-2790
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2791-2880
# Pattern: Symmetrical Triangle (Confidence: 0.4016)
# Bounding Box: x_min=2011-03-30 00:00:00, y_min=1175.0, x_max=2011-07-12 00:00:00, y_max=1460.45
#
# Period: 2881-2970
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2011-07-25 00:00:00, y_min=1180.9, x_max=2011-08-10 00:00:00, y_max=1367.55
#
# Period: 2971-3060
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3061-3150
# Pattern: Symmetrical Triangle (Confidence: 0.5468)
# Bounding Box: x_min=2012-04-12 00:00:00, y_min=922.0, x_max=2012-08-08 00:00:00, y_max=1226.5
#
# Period: 3151-3240
# Pattern: Triple Bottom Reversal (Confidence: 0.5048)
# Bounding Box: x_min=2012-09-05 00:00:00, y_min=927.25, x_max=2012-09-13 00:00:00, y_max=984.0
#
# Period: 3241-3330
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3331-3420
# Pattern: Symmetrical Triangle (Confidence: 0.3176)
# Bounding Box: x_min=2013-05-07 00:00:00, y_min=763.4, x_max=2013-09-10 00:00:00, y_max=1549.9
#
# Period: 3421-3510
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3511-3600
# Pattern: Symmetrical Triangle (Confidence: 0.1706)
# Bounding Box: x_min=2014-05-13 00:00:00, y_min=1630.35, x_max=2014-06-03 00:00:00, y_max=1928.8
#
# Period: 3601-3690
# Pattern: Symmetrical Triangle (Confidence: 0.1806)
# Bounding Box: x_min=2014-06-06 00:00:00, y_min=369.05, x_max=2014-10-16 00:00:00, y_max=2043.05
#
# Period: 3691-3780
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3781-3870
# Pattern: Double Bottom (Confidence: 0.6106)
# Bounding Box: x_min=2015-05-07 00:00:00, y_min=523.3, x_max=2015-05-12 00:00:00, y_max=553.9
#
# Period: 3871-3960
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2015-07-29 00:00:00, y_min=554.85, x_max=2015-08-14 00:00:00, y_max=589.5
#
# Period: 3961-4050
# Pattern: Triple Bottom Reversal (Confidence: 0.6805)
# Bounding Box: x_min=2016-02-11 00:00:00, y_min=373.3, x_max=2016-02-29 00:00:00, y_max=422.5
#
# Period: 4051-4140
# Pattern: Ascending Triangle (Confidence: 0.4959)
# Bounding Box: x_min=2016-07-12 00:00:00, y_min=518.5, x_max=2016-08-11 00:00:00, y_max=576.8
#
# Period: 4141-4230
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2016-09-14 00:00:00, y_min=583.3, x_max=2016-09-21 00:00:00, y_max=612.4
#
# Period: 4231-4320
# Pattern: Ascending Triangle (Confidence: 0.2117)
# Bounding Box: x_min=2017-02-23 00:00:00, y_min=481.0, x_max=2017-05-08 00:00:00, y_max=530.0
#
# Period: 4321-4410
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4411-4500
# Pattern: Inverse Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2017-10-05 00:00:00, y_min=447.5, x_max=2017-10-30 00:00:00, y_max=534.65
#
# Period: 4501-4590
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4591-4680
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2018-09-04 00:00:00, y_min=622.75, x_max=2018-09-14 00:00:00, y_max=677.95
#
# Period: 4681-4770
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4771-4860
# Pattern: Ascending Triangle (Confidence: 0.3283)
# Bounding Box: x_min=2019-05-27 00:00:00, y_min=756.55, x_max=2019-07-11 00:00:00, y_max=827.75
#
# Period: 4861-4950
# Pattern: Cup and Handle (Confidence: 0.1000)
# Bounding Box: x_min=2019-09-19 00:00:00, y_min=622.65, x_max=2019-11-26 00:00:00, y_max=762.0
#
# Period: 4951-5040
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 5041-5130
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 5131-5220
# Pattern: No Pattern Detected (Confidence: 0.0000)

# %%
pattern_functions = [
    detect_head_and_shoulders, detect_symmetrical_triangle, detect_cup_and_handle,
    detect_ascending_triangle, detect_descending_triangle, detect_inverse_head_and_shoulders,
    detect_falling_wedge, detect_rounding_bottom, detect_triple_bottom_reversal,
    detect_double_top, detect_double_bottom, detect_flag_and_pole
]

# %%
import os
def process_nifty_fifty_directory(directory="/content/drive/MyDrive/nifty 50",
                                  output_csv="/content/drive/MyDrive/nifty50_labels.csv"):
    total_segments = 0
    detected_segments = 0
    all_results = []

    # Ensure the directory exists
    if not os.path.exists(directory):
        print(f"Directory '{directory}' does not exist.")
        return None

    # Iterate through all CSV files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            company = filename.replace('.csv', '')
            filepath = os.path.join(directory, filename)
            print(f"\n=== Processing file: {filename} ===")

            try:
                # Process the CSV file
                file_results = process_patterns(filepath)

                # Convert results to DataFrame format
                for result in file_results:
                    period = result["label"]
                    company_period = f"{company}_{period}"
                    if result["pattern"] != "No Pattern Detected" and result["bounding_box"]:
                        all_results.append({
                            "Company_Period": company_period,
                            "Label": result["pattern"],
                            "Confidence": result["confidence"],
                            "x_min": result["bounding_box"]["x_min"],
                            "y_min": result["bounding_box"]["y_min"],
                            "x_max": result["bounding_box"]["x_max"],
                            "y_max": result["bounding_box"]["y_max"]
                        })
                    else:
                        all_results.append({
                            "Company_Period": company_period,
                            "Label": result["pattern"],
                            "Confidence": 0.0,
                            "x_min": None,
                            "y_min": None,
                            "x_max": None,
                            "y_max": None
                        })

                # Update segment counts
                file_detected = sum(1 for r in file_results if r["pattern"] != "No Pattern Detected")
                file_total = len(file_results)
                total_segments += file_total
                detected_segments += file_detected

            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")

    # Create DataFrame
    results_df = pd.DataFrame(all_results)

    # Overall summary
    detection_rate = (detected_segments / total_segments) * 100 if total_segments > 0 else 0
    print(f"\n=== Overall Summary ===")
    print(f"Total files processed: {len([f for f in os.listdir(directory) if f.endswith('.csv')])}")
    print(f"Detected patterns in {detected_segments}/{total_segments} segments across all files ({detection_rate:.1f}%)")

    # Save DataFrame to CSV
    results_df.to_csv(output_csv, index=False)
    print(f"Saved labels to {output_csv}")

    return results_df

# Updated main block
if __name__ == "__main__":
    results_df = process_nifty_fifty_directory("/content/drive/MyDrive/nifty 50")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Period: 1891-1980
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1981-2070
# Pattern: Double Top (Confidence: 0.3049)
# Bounding Box: x_min=2008-01-07 00:00:00, y_min=530.5, x_max=2008-02-04 00:00:00, y_max=807.8
#
# Period: 2071-2160
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2161-2250
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2251-2340
# Pattern: Triple Bottom Reversal (Confidence: 0.5864)
# Bounding Box: x_min=2009-02-05 00:00:00, y_min=128.0, x_max=2009-02-24 00:00:00, y_max=144.1
#
# Period: 2341-2430
# Pattern: Triple Bottom Reversal (Confidence: 0.8093)
# Bounding Box: x_min=2009-07-02 00:00:00, y_min=254.1, x_max=2009-07-13 00:00:00, y_max=307.7
#
# Period: 2431-2520
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2521-2610
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2611-2700
# Pattern: Symmetrical Triangle (Confidence: 0.5213)
# Bounding Box: x_min=2010-10-04 00:00:00, y_min=1093.0, x_max=2010-10-22 00:00:00, y_max=1195.0
#
# Period: 2701-2790
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2791-2880
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2881-2970
# Pattern: Descending Triangle (Confidence: 0.7833)
# Bounding Box: x_min=2011-07-14 00:00:00, y_min=137.55, x_max=2011-11-24 00:00:00, y_max=1081.5
#
# Period: 2971-3060
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3061-3150
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3151-3240
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3241-3330
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3331-3420
# Pattern: Triple Bottom Reversal (Confidence: 0.2684)
# Bounding Box: x_min=2013-07-10 00:00:00, y_min=271.8, x_max=2013-08-21 00:00:00, y_max=324.4
#
# Period: 3421-3510
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2013-11-27 00:00:00, y_min=385.95, x_max=2013-12-09 00:00:00, y_max=405.05
#
# Period: 3511-3600
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3601-3690
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3691-3780
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3781-3870
# Pattern: Descending Triangle (Confidence: 0.4188)
# Bounding Box: x_min=2015-02-28 00:00:00, y_min=394.25, x_max=2015-07-09 00:00:00, y_max=601.0
#
# Period: 3871-3960
# Pattern: Inverse Head and Shoulders (Confidence: 0.8759)
# Bounding Box: x_min=2015-09-07 00:00:00, y_min=279.1, x_max=2015-10-01 00:00:00, y_max=358.9
#
# Period: 3961-4050
# Pattern: Triple Bottom Reversal (Confidence: 0.7627)
# Bounding Box: x_min=2016-02-16 00:00:00, y_min=290.25, x_max=2016-02-29 00:00:00, y_max=324.75
#
# Period: 4051-4140
# Pattern: Symmetrical Triangle (Confidence: 0.6303)
# Bounding Box: x_min=2016-07-19 00:00:00, y_min=475.5, x_max=2016-08-11 00:00:00, y_max=522.6
#
# Period: 4141-4230
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4231-4320
# Pattern: Double Top (Confidence: 0.4921)
# Bounding Box: x_min=2017-02-01 00:00:00, y_min=519.5, x_max=2017-02-06 00:00:00, y_max=544.5
#
# Period: 4321-4410
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4411-4500
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4501-4590
# Pattern: Descending Triangle (Confidence: 0.7203)
# Bounding Box: x_min=2018-01-24 00:00:00, y_min=281.6, x_max=2018-06-06 00:00:00, y_max=416.25
#
# Period: 4591-4680
# Pattern: Symmetrical Triangle (Confidence: 0.7460)
# Bounding Box: x_min=2018-06-08 00:00:00, y_min=170.3, x_max=2018-10-17 00:00:00, y_max=315.55
#
# Period: 4681-4770
# Pattern: Descending Triangle (Confidence: 0.3658)
# Bounding Box: x_min=2018-11-02 00:00:00, y_min=129.0, x_max=2019-02-26 00:00:00, y_max=200.75
#
# Period: 4771-4860
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2019-04-15 00:00:00, y_min=203.05, x_max=2019-05-03 00:00:00, y_max=239.35
#
# Period: 4861-4950
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4951-5040
# Pattern: Double Top (Confidence: 0.6807)
# Bounding Box: x_min=2020-01-23 00:00:00, y_min=174.9, x_max=2020-01-29 00:00:00, y_max=191.0
#
# Period: 5041-5130
# Pattern: Triple Bottom Reversal (Confidence: 0.7141)
# Bounding Box: x_min=2020-04-21 00:00:00, y_min=72.55, x_max=2020-05-18 00:00:00, y_max=93.75
#
# Period: 5131-5220
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
#
# === Processing file: SUNPHARMA.csv ===
#
# Processing segment: 1-90
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 653.46
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 68.280000, Min slope: -43.425000, max_r²: 0.2001, min_r²: 0.4361
# Slopes not steep enough or weak fit: Max slope 68.280000 > -0.0012, Min slope -43.425000 > -0.0012, max_r² 0.2001 <= 0.25, min_r² 0.4361 <= 0.25
#
# Processing segment: 91-180
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0156 < 0.2 or min_r² 0.6818 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 751.80
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.005000, Min slope: 17.370000, max_r²: 0.0000, min_r²: 0.8116
# Slopes not steep enough or weak fit: Max slope -0.005000 > -0.0012, Min slope 17.370000 > -0.0012, max_r² 0.0000 <= 0.25, min_r² 0.8116 <= 0.25
#
# Processing segment: 181-270
# Neckline too steep or weak fit: Slope 0.000003 > 0.0024 or R² 0.0231 < 0.15
# Trendlines too weak: max_r² 0.0372 < 0.2 or min_r² 0.0151 < 0.2
# Handle max invalid: Exists: True, Days: 98 < 5, Value: 573.85 > 563.94
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.175000, Min slope: 0.270000, max_r²: 0.0010, min_r²: 0.0011
# Slopes not steep enough or weak fit: Max slope -0.175000 > -0.0012, Min slope 0.270000 > -0.0012, max_r² 0.0010 <= 0.25, min_r² 0.0011 <= 0.25
# Detected Double Bottom with confidence 0.3354
#
# Processing segment: 271-360
# Failed shoulder-head condition
# Close: 589.10, Neckline: 543.90, Threshold: 545.53
# Trend: neutral, RSI: 60.20
# Trend not bullish or RSI too low: Trend neutral, RSI 60.20 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.530000, Min slope: 12.465000, max_r²: 0.3713, min_r²: 0.4921
# Slopes not steep enough or weak fit: Max slope -2.530000 > -0.0012, Min slope 12.465000 > -0.0012, max_r² 0.3713 <= 0.25, min_r² 0.4921 <= 0.25
#
# Processing segment: 361-450
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1613 < 0.2 or min_r² 0.6688 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 643.44
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.335000, Min slope: 3.495000, max_r²: 0.3166, min_r²: 0.6058
# Slopes not steep enough or weak fit: Max slope -2.335000 > -0.0012, Min slope 3.495000 > -0.0012, max_r² 0.3166 <= 0.25, min_r² 0.6058 <= 0.25
#
# Processing segment: 451-540
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0644 < 0.2 or min_r² 0.3515 < 0.2
# Close: 640.05, Neckline: 584.40, Threshold: 586.15
# Trend: bullish, RSI: 69.07
# Detected Cup and Handle with confidence 0.4724
# Detected Cup and Handle with confidence 0.4724
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -4.920000, Min slope: -0.880000, max_r²: 0.1265, min_r²: 0.4535
# Slopes not steep enough or weak fit: Max slope -4.920000 > -0.0012, Min slope -0.880000 > -0.0012, max_r² 0.1265 <= 0.25, min_r² 0.4535 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5314
#
# Processing segment: 541-630
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.9722 < 0.2 or min_r² 0.0704 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 672.60
# Detected Descending Triangle with confidence 0.7538
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -6.515000, Min slope: 0.410000, max_r²: 0.9422, min_r²: 0.0184
# Slopes not steep enough or weak fit: Max slope -6.515000 > -0.0012, Min slope 0.410000 > -0.0012, max_r² 0.9422 <= 0.25, min_r² 0.0184 <= 0.25
#
# Processing segment: 631-720
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.6670
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 687.00
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.415000, Min slope: -3.575000, max_r²: 0.7413, min_r²: 0.8534
# Breakout check: 446.14 < Close 542.70 < 743.56
# Trend: bearish, RSI: 33.48
# Trend not bullish or RSI too low: Trend bearish, RSI 33.48 <= 30
#
# Processing segment: 721-810
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.9642 < 0.2 or min_r² 0.0928 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 331.08
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 16.640000, Min slope: -0.690000, max_r²: 0.9272, min_r²: 0.0856
# Slopes not steep enough or weak fit: Max slope 16.640000 > -0.0012, Min slope -0.690000 > -0.0012, max_r² 0.9272 <= 0.25, min_r² 0.0856 <= 0.25
# Detected Double Top with confidence 0.1266
#
# Processing segment: 811-900
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2497
# Handle max invalid: Exists: True, Days: 89 < 5, Value: 453.45 > 347.34
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 18.810000, Min slope: 1.200000, max_r²: 0.6652, min_r²: 0.2793
# Slopes not steep enough or weak fit: Max slope 18.810000 > -0.0012, Min slope 1.200000 > -0.0012, max_r² 0.6652 <= 0.25, min_r² 0.2793 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5833
#
# Processing segment: 901-990
# Detected Symmetrical Triangle with confidence 0.5722
# Handle max invalid: Exists: True, Days: 77 < 5, Value: 652.3 > 554.94
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 16.000000, Min slope: 5.515000, max_r²: 0.7778, min_r²: 0.6154
# Slopes not steep enough or weak fit: Max slope 16.000000 > -0.0012, Min slope 5.515000 > -0.0012, max_r² 0.7778 <= 0.25, min_r² 0.6154 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.6338
#
# Processing segment: 991-1080
# Trendlines too weak: max_r² 0.3058 < 0.2 or min_r² 0.0520 < 0.2
# Close: 711.75, Neckline: 593.80, Threshold: 595.58
# Trend: bullish, RSI: 58.57
# Detected Cup and Handle with confidence 0.5699
# Detected Cup and Handle with confidence 0.5699
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 6.640000, Min slope: 0.225000, max_r²: 0.2272, min_r²: 0.0108
# Slopes not steep enough or weak fit: Max slope 6.640000 > -0.0012, Min slope 0.225000 > -0.0012, max_r² 0.2272 <= 0.25, min_r² 0.0108 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.6411
#
# Processing segment: 1081-1170
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0011 < 0.2 or min_r² 0.0410 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 438.60
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.100000, Min slope: 1.415000, max_r²: 0.0002, min_r²: 0.1140
# Slopes not steep enough or weak fit: Max slope 0.100000 > -0.0012, Min slope 1.415000 > -0.0012, max_r² 0.0002 <= 0.25, min_r² 0.1140 <= 0.25
#
# Processing segment: 1171-1260
# Detected Symmetrical Triangle with confidence 0.4621
# Handle max invalid: Exists: True, Days: 102 < 5, Value: 557.0 > 499.08
# Detected Ascending Triangle with confidence 0.5736
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 10.090000, Min slope: 7.395000, max_r²: 0.4543, min_r²: 0.7170
# Slopes not steep enough or weak fit: Max slope 10.090000 > -0.0012, Min slope 7.395000 > -0.0012, max_r² 0.4543 <= 0.25, min_r² 0.7170 <= 0.25
#
# Processing segment: 1261-1350
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.4424 < 0.2 or min_r² 0.1865 < 0.2
# Close: 509.85, Neckline: 462.30, Threshold: 463.69
# Trend: bullish, RSI: 63.26
# Detected Cup and Handle with confidence 0.3972
# Detected Cup and Handle with confidence 0.3972
# Detected Ascending Triangle with confidence 0.4013
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.885000, Min slope: 4.545000, max_r²: 0.1847, min_r²: 0.5016
# Slopes not steep enough or weak fit: Max slope 1.885000 > -0.0012, Min slope 4.545000 > -0.0012, max_r² 0.1847 <= 0.25, min_r² 0.5016 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.4469
#
# Processing segment: 1351-1440
# Detected Symmetrical Triangle with confidence 0.2442
# Handle max invalid: Exists: True, Days: 99 < 5, Value: 666.05 > 660.12
# Detected Ascending Triangle with confidence 0.6107
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 6.660000, Min slope: 9.615000, max_r²: 0.5339, min_r²: 0.7634
# Slopes not steep enough or weak fit: Max slope 6.660000 > -0.0012, Min slope 9.615000 > -0.0012, max_r² 0.5339 <= 0.25, min_r² 0.7634 <= 0.25
# Detected Flag and Pole with confidence 0.6624
#
# Processing segment: 1441-1530
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1147 < 0.2 or min_r² 0.5648 < 0.2
# Insufficient post-handle data: 1 < 2
# Detected Ascending Triangle with confidence 0.3747
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 6.700000, Min slope: 8.980000, max_r²: 0.1931, min_r²: 0.4684
# Slopes not steep enough or weak fit: Max slope 6.700000 > -0.0012, Min slope 8.980000 > -0.0012, max_r² 0.1931 <= 0.25, min_r² 0.4684 <= 0.25
#
# Processing segment: 1531-1620
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0505 < 0.2 or min_r² 0.9631 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 864.84
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.250000, Min slope: -23.640000, max_r²: 0.0534, min_r²: 0.7251
# Slopes not steep enough or weak fit: Max slope -2.250000 > -0.0012, Min slope -23.640000 > -0.0012, max_r² 0.0534 <= 0.25, min_r² 0.7251 <= 0.25
# Detected Double Top with confidence 0.7280
#
# Processing segment: 1621-1710
# Handle max invalid: Exists: True, Days: 91 < 5, Value: 926.9 > 903.54
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.575000, Min slope: 8.285000, max_r²: 0.3584, min_r²: 0.5685
# Slopes not steep enough or weak fit: Max slope -1.575000 > -0.0012, Min slope 8.285000 > -0.0012, max_r² 0.3584 <= 0.25, min_r² 0.5685 <= 0.25
#
# Processing segment: 1711-1800
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0197 < 0.2 or min_r² 0.9921 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1271.76
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.990000, Min slope: 4.965000, max_r²: 0.0797, min_r²: 0.5137
# Slopes not steep enough or weak fit: Max slope 0.990000 > -0.0012, Min slope 4.965000 > -0.0012, max_r² 0.0797 <= 0.25, min_r² 0.5137 <= 0.25
#
# Processing segment: 1801-1890
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0039 < 0.2 or min_r² 0.0803 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1343.16
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 5.180000, Min slope: 6.410000, max_r²: 0.0532, min_r²: 0.2613
# Slopes not steep enough or weak fit: Max slope 5.180000 > -0.0012, Min slope 6.410000 > -0.0012, max_r² 0.0532 <= 0.25, min_r² 0.2613 <= 0.25
#
# Processing segment: 1891-1980
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.3808
# Handle max invalid: Exists: True, Days: 82 < 5, Value: 1146.1 > 1090.02
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 22.345000, Min slope: -2.630000, max_r²: 0.7272, min_r²: 0.2818
# Slopes not steep enough or weak fit: Max slope 22.345000 > -0.0012, Min slope -2.630000 > -0.0012, max_r² 0.7272 <= 0.25, min_r² 0.2818 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5563
#
# Processing segment: 1981-2070
# Trendlines too weak: max_r² 0.0152 < 0.2 or min_r² 0.0065 < 0.2
# Close: 1199.95, Neckline: 1124.05, Threshold: 1127.42
# Trend: neutral, RSI: 39.86
# Trend not bullish or RSI too low: Trend neutral, RSI 39.86 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.590000, Min slope: 9.110000, max_r²: 0.0018, min_r²: 0.0357
# Slopes not steep enough or weak fit: Max slope 0.590000 > -0.0012, Min slope 9.110000 > -0.0012, max_r² 0.0018 <= 0.25, min_r² 0.0357 <= 0.25
#
# Processing segment: 2071-2160
# Failed shoulder-head condition
# Close: 1450.15, Neckline: 1275.25, Threshold: 1279.08
# Trend: bullish, RSI: 59.14
# Detected Cup and Handle with confidence 0.5138
# Detected Cup and Handle with confidence 0.5138
# Detected Ascending Triangle with confidence 0.5447
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.470000, Min slope: 8.645000, max_r²: 0.0027, min_r²: 0.6809
# Slopes not steep enough or weak fit: Max slope 0.470000 > -0.0012, Min slope 8.645000 > -0.0012, max_r² 0.0027 <= 0.25, min_r² 0.6809 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5780
#
# Processing segment: 2161-2250
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0952 < 0.2 or min_r² 0.0841 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1306.50
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.475000, Min slope: -5.715000, max_r²: 0.0858, min_r²: 0.1136
# Slopes not steep enough or weak fit: Max slope -3.475000 > -0.0012, Min slope -5.715000 > -0.0012, max_r² 0.0858 <= 0.25, min_r² 0.1136 <= 0.25
#
# Processing segment: 2251-2340
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4663
# Handle max invalid: Exists: True, Days: 62 < 5, Value: 1590.05 > 1233.18
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 77.290000, Min slope: -12.555000, max_r²: 0.6845, min_r²: 0.5173
# Slopes not steep enough or weak fit: Max slope 77.290000 > -0.0012, Min slope -12.555000 > -0.0012, max_r² 0.6845 <= 0.25, min_r² 0.5173 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.4795
#
# Processing segment: 2341-2430
# Failed shoulder-head condition
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1525.08
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -7.695000, Min slope: 9.570000, max_r²: 0.5016, min_r²: 0.4335
# Slopes not steep enough or weak fit: Max slope -7.695000 > -0.0012, Min slope 9.570000 > -0.0012, max_r² 0.5016 <= 0.25, min_r² 0.4335 <= 0.25
#
# Processing segment: 2431-2520
# Close: 1473.90, Neckline: 1403.20, Threshold: 1407.41
# Trend: neutral, RSI: 40.21
# Trend not bullish or RSI too low: Trend neutral, RSI 40.21 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 4.715000, Min slope: 28.445000, max_r²: 0.2777, min_r²: 0.4508
# Slopes not steep enough or weak fit: Max slope 4.715000 > -0.0012, Min slope 28.445000 > -0.0012, max_r² 0.2777 <= 0.25, min_r² 0.4508 <= 0.25
#
# Processing segment: 2521-2610
# Trendlines too weak: max_r² 0.0784 < 0.2 or min_r² 0.6519 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1872.30
# Detected Ascending Triangle with confidence 0.7049
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.460000, Min slope: 11.705000, max_r²: 0.0890, min_r²: 0.8811
# Slopes not steep enough or weak fit: Max slope -3.460000 > -0.0012, Min slope 11.705000 > -0.0012, max_r² 0.0890 <= 0.25, min_r² 0.8811 <= 0.25
#
# Processing segment: 2611-2700
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.7605 < 0.2 or min_r² 0.0928 < 0.2
# Handle max invalid: Exists: True, Days: 45 < 5, Value: 2139.8 > 2074.20
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 40.255000, Min slope: 1.425000, max_r²: 0.6428, min_r²: 0.0992
# Slopes not steep enough or weak fit: Max slope 40.255000 > -0.0012, Min slope 1.425000 > -0.0012, max_r² 0.6428 <= 0.25, min_r² 0.0992 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.4946
#
# Processing segment: 2701-2790
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 516.48
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 45.350000, Min slope: -5.840000, max_r²: 0.7861, min_r²: 0.3844
# Slopes not steep enough or weak fit: Max slope 45.350000 > -0.0012, Min slope -5.840000 > -0.0012, max_r² 0.7861 <= 0.25, min_r² 0.3844 <= 0.25
#
# Processing segment: 2791-2880
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.7349
# Close: 500.10, Neckline: 439.25, Threshold: 440.57
# Trend: bullish, RSI: 57.16
# Detected Cup and Handle with confidence 0.5091
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 3.135000, Min slope: 2.820000, max_r²: 0.9197, min_r²: 0.5932
# Slopes not steep enough or weak fit: Max slope 3.135000 > -0.0012, Min slope 2.820000 > -0.0012, max_r² 0.9197 <= 0.25, min_r² 0.5932 <= 0.25
#
# Processing segment: 2881-2970
# Neckline too steep or weak fit: Slope 0.000000 > 0.0024 or R² 0.0003 < 0.15
# Trendlines too weak: max_r² 0.1312 < 0.2 or min_r² 0.0814 < 0.2
# Close: 501.70, Neckline: 484.05, Threshold: 485.50
# Trend: neutral, RSI: 46.39
# Trend not bullish or RSI too low: Trend neutral, RSI 46.39 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.235000, Min slope: -0.040000, max_r²: 0.0034, min_r²: 0.0001
# Slopes not steep enough or weak fit: Max slope 0.235000 > -0.0012, Min slope -0.040000 > -0.0012, max_r² 0.0034 <= 0.25, min_r² 0.0001 <= 0.25
#
# Processing segment: 2971-3060
# Trendlines too weak: max_r² 0.0133 < 0.2 or min_r² 0.7223 < 0.2
# Handle not in strict downtrend
# Detected Ascending Triangle with confidence 0.5479
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.125000, Min slope: 1.495000, max_r²: 0.0007, min_r²: 0.6848
# Slopes not steep enough or weak fit: Max slope -0.125000 > -0.0012, Min slope 1.495000 > -0.0012, max_r² 0.0007 <= 0.25, min_r² 0.6848 <= 0.25
#
# Processing segment: 3061-3150
# Failed shoulder-head condition
# Insufficient post-handle data: 1 < 2
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 11.100000, Min slope: -0.180000, max_r²: 0.8983, min_r²: 0.0039
# Slopes not steep enough or weak fit: Max slope 11.100000 > -0.0012, Min slope -0.180000 > -0.0012, max_r² 0.8983 <= 0.25, min_r² 0.0039 <= 0.25
#
# Processing segment: 3151-3240
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2501 < 0.2 or min_r² 0.0283 < 0.2
# Close: 747.00, Neckline: 685.05, Threshold: 687.11
# Trend: bullish, RSI: 67.13
# Detected Cup and Handle with confidence 0.5096
# Detected Cup and Handle with confidence 0.5096
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 9.025000, Min slope: 0.310000, max_r²: 0.4525, min_r²: 0.0046
# Slopes not steep enough or weak fit: Max slope 9.025000 > -0.0012, Min slope 0.310000 > -0.0012, max_r² 0.4525 <= 0.25, min_r² 0.0046 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5733
#
# Processing segment: 3241-3330
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2252
# Handle max invalid: Exists: True, Days: 88 < 5, Value: 984.7 > 863.88
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 35.260000, Min slope: -1.930000, max_r²: 0.7949, min_r²: 0.0556
# Slopes not steep enough or weak fit: Max slope 35.260000 > -0.0012, Min slope -1.930000 > -0.0012, max_r² 0.7949 <= 0.25, min_r² 0.0556 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7890
#
# Processing segment: 3331-3420
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.0041 < 0.2 or min_r² 0.1951 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 623.76
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.425000, Min slope: 5.615000, max_r²: 0.0119, min_r²: 0.3910
# Slopes not steep enough or weak fit: Max slope 0.425000 > -0.0012, Min slope 5.615000 > -0.0012, max_r² 0.0119 <= 0.25, min_r² 0.3910 <= 0.25
#
# Processing segment: 3421-3510
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 699.48
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.535000, Min slope: 3.255000, max_r²: 0.3448, min_r²: 0.4067
# Slopes not steep enough or weak fit: Max slope -3.535000 > -0.0012, Min slope 3.255000 > -0.0012, max_r² 0.3448 <= 0.25, min_r² 0.4067 <= 0.25
#
# Processing segment: 3511-3600
# Detected Symmetrical Triangle with confidence 0.1967
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 767.34
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.845000, Min slope: 1.915000, max_r²: 0.1676, min_r²: 0.2452
# Slopes not steep enough or weak fit: Max slope -1.845000 > -0.0012, Min slope 1.915000 > -0.0012, max_r² 0.1676 <= 0.25, min_r² 0.2452 <= 0.25
# Detected Double Top with confidence 0.3411
#
# Processing segment: 3601-3690
# Detected Symmetrical Triangle with confidence 0.2877
# Handle max invalid: Exists: True, Days: 99 < 5, Value: 860.8 > 760.74
# Detected Ascending Triangle with confidence 0.3502
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.385000, Min slope: 6.510000, max_r²: 0.0550, min_r²: 0.4377
# Slopes not steep enough or weak fit: Max slope -0.385000 > -0.0012, Min slope 6.510000 > -0.0012, max_r² 0.0550 <= 0.25, min_r² 0.4377 <= 0.25
#
# Processing segment: 3691-3780
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0501 < 0.2 or min_r² 0.5032 < 0.2
# Close: 878.90, Neckline: 826.75, Threshold: 829.23
# Trend: neutral, RSI: 34.99
# Trend not bullish or RSI too low: Trend neutral, RSI 34.99 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.620000, Min slope: 2.070000, max_r²: 0.0051, min_r²: 0.5340
# Slopes not steep enough or weak fit: Max slope -0.620000 > -0.0012, Min slope 2.070000 > -0.0012, max_r² 0.0051 <= 0.25, min_r² 0.5340 <= 0.25
#
# Processing segment: 3781-3870
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0976 < 0.2 or min_r² 0.4886 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 1045.32
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 9.100000, Min slope: 7.130000, max_r²: 0.0540, min_r²: 0.3960
# Slopes not steep enough or weak fit: Max slope 9.100000 > -0.0012, Min slope 7.130000 > -0.0012, max_r² 0.0540 <= 0.25, min_r² 0.3960 <= 0.25
#
# Processing segment: 3871-3960
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2789
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 895.92
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -5.870000, Min slope: -22.140000, max_r²: 0.2617, min_r²: 0.6606
# Breakout check: 711.00 < Close 742.50 < 1185.00
# Trend: bearish, RSI: 19.50
# Trend not bullish or RSI too low: Trend bearish, RSI 19.50 <= 30
#
# Processing segment: 3961-4050
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0056 < 0.2 or min_r² 0.8065 < 0.2
# Close: 815.10, Neckline: 802.25, Threshold: 804.66
# Trend: neutral, RSI: 35.13
# Trend not bullish or RSI too low: Trend neutral, RSI 35.13 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.080000, Min slope: 12.355000, max_r²: 0.0007, min_r²: 0.8617
# Slopes not steep enough or weak fit: Max slope 0.080000 > -0.0012, Min slope 12.355000 > -0.0012, max_r² 0.0007 <= 0.25, min_r² 0.8617 <= 0.25
#
# Processing segment: 4051-4140
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2393 < 0.2 or min_r² 0.1795 < 0.2
# Close: 808.25, Neckline: 754.60, Threshold: 756.86
# Trend: bullish, RSI: 58.53
# Detected Cup and Handle with confidence 0.4986
# Detected Cup and Handle with confidence 0.4986
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.425000, Min slope: 3.740000, max_r²: 0.2010, min_r²: 0.3645
# Slopes not steep enough or weak fit: Max slope 2.425000 > -0.0012, Min slope 3.740000 > -0.0012, max_r² 0.2010 <= 0.25, min_r² 0.3645 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.5610
#
# Processing segment: 4141-4230
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0033 < 0.2 or min_r² 0.2177 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 821.22
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.040000, Min slope: -5.610000, max_r²: 0.0000, min_r²: 0.1380
# Slopes not steep enough or weak fit: Max slope -0.040000 > -0.0012, Min slope -5.610000 > -0.0012, max_r² 0.0000 <= 0.25, min_r² 0.1380 <= 0.25
#
# Processing segment: 4231-4320
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0608 < 0.2 or min_r² 0.7427 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 852.96
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.360000, Min slope: 4.355000, max_r²: 0.0073, min_r²: 0.8591
# Slopes not steep enough or weak fit: Max slope 0.360000 > -0.0012, Min slope 4.355000 > -0.0012, max_r² 0.0073 <= 0.25, min_r² 0.8591 <= 0.25
# Detected Double Top with confidence 0.6823
#
# Processing segment: 4321-4410
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 576.54
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -21.600000, Min slope: 4.860000, max_r²: 0.6929, min_r²: 0.6720
# Slopes not steep enough or weak fit: Max slope -21.600000 > -0.0012, Min slope 4.860000 > -0.0012, max_r² 0.6929 <= 0.25, min_r² 0.6720 <= 0.25
#
# Processing segment: 4411-4500
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.3739 < 0.2 or min_r² 0.0272 < 0.2
# Close: 579.35, Neckline: 563.45, Threshold: 565.14
# Trend: bullish, RSI: 56.91
# Detected Cup and Handle with confidence 0.1000
# Detected Cup and Handle with confidence 0.1000
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.165000, Min slope: -0.500000, max_r²: 0.3338, min_r²: 0.0290
# Slopes not steep enough or weak fit: Max slope 2.165000 > -0.0012, Min slope -0.500000 > -0.0012, max_r² 0.3338 <= 0.25, min_r² 0.0290 <= 0.25
#
# Processing segment: 4501-4590
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.7866 < 0.2 or min_r² 0.0006 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 599.64
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -5.295000, Min slope: -1.350000, max_r²: 0.8102, min_r²: 0.0258
# Slopes not steep enough or weak fit: Max slope -5.295000 > -0.0012, Min slope -1.350000 > -0.0012, max_r² 0.8102 <= 0.25, min_r² 0.0258 <= 0.25
#
# Processing segment: 4591-4680
# Failed shoulder-head condition
# Close: 593.45, Neckline: 585.85, Threshold: 587.61
# Trend: neutral, RSI: 31.43
# Trend not bullish or RSI too low: Trend neutral, RSI 31.43 <= 35
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -5.875000, Min slope: 12.095000, max_r²: 0.4308, min_r²: 0.4909
# Slopes not steep enough or weak fit: Max slope -5.875000 > -0.0012, Min slope 12.095000 > -0.0012, max_r² 0.4308 <= 0.25, min_r² 0.4909 <= 0.25
#
# Processing segment: 4681-4770
# Trendlines too weak: max_r² 0.6296 < 0.2 or min_r² 0.0743 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 508.14
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -13.035000, Min slope: 2.240000, max_r²: 0.4913, min_r²: 0.1453
# Slopes not steep enough or weak fit: Max slope -13.035000 > -0.0012, Min slope 2.240000 > -0.0012, max_r² 0.4913 <= 0.25, min_r² 0.1453 <= 0.25
#
# Processing segment: 4771-4860
# Trendlines too weak: max_r² 0.0332 < 0.2 or min_r² 0.8439 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 486.42
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.740000, Min slope: -5.325000, max_r²: 0.0981, min_r²: 0.7176
# Slopes not steep enough or weak fit: Max slope 0.740000 > -0.0012, Min slope -5.325000 > -0.0012, max_r² 0.0981 <= 0.25, min_r² 0.7176 <= 0.25
#
# Processing segment: 4861-4950
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2651 < 0.2 or min_r² 0.0066 < 0.2
# Close: 450.75, Neckline: 405.45, Threshold: 406.67
# Trend: bullish, RSI: 59.68
# Detected Cup and Handle with confidence 0.1457
# Detected Cup and Handle with confidence 0.1457
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 3.760000, Min slope: -0.335000, max_r²: 0.5673, min_r²: 0.0019
# Slopes not steep enough or weak fit: Max slope 3.760000 > -0.0012, Min slope -0.335000 > -0.0012, max_r² 0.5673 <= 0.25, min_r² 0.0019 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.1639
#
# Processing segment: 4951-5040
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2396
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 422.76
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.825000, Min slope: -5.020000, max_r²: 0.0775, min_r²: 0.2830
# Slopes not steep enough or weak fit: Max slope -0.825000 > -0.0012, Min slope -5.020000 > -0.0012, max_r² 0.0775 <= 0.25, min_r² 0.2830 <= 0.25
#
# Processing segment: 5041-5130
# Failed shoulder-head condition
# Close: 531.35, Neckline: 469.40, Threshold: 470.81
# Trend: bullish, RSI: 70.04
# Detected Cup and Handle with confidence 0.6216
# Detected Cup and Handle with confidence 0.6216
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 8.105000, Min slope: 5.860000, max_r²: 0.7472, min_r²: 0.4067
# Slopes not steep enough or weak fit: Max slope 8.105000 > -0.0012, Min slope 5.860000 > -0.0012, max_r² 0.7472 <= 0.25, min_r² 0.4067 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.6993
#
# Processing segment: 5131-5220
# Trendlines too weak: max_r² 0.0314 < 0.2 or min_r² 0.1816 < 0.2
# Close: 568.30, Neckline: 512.50, Threshold: 514.04
# Trend: bullish, RSI: 59.52
# Detected Cup and Handle with confidence 0.4698
# Detected Cup and Handle with confidence 0.4698
# Detected Inverse Head and Shoulders with confidence 0.8229
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.755000, Min slope: -3.925000, max_r²: 0.0689, min_r²: 0.1633
# Slopes not steep enough or weak fit: Max slope -0.755000 > -0.0012, Min slope -3.925000 > -0.0012, max_r² 0.0689 <= 0.25, min_r² 0.1633 <= 0.25
# Detected patterns in 34/58 segments (58.6%)
# Period: 1-90
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2000-02-24 00:00:00, y_min=2421.0, x_max=2000-03-02 00:00:00, y_max=3107.0
#
# Period: 91-180
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 181-270
# Pattern: Double Bottom (Confidence: 0.3354)
# Bounding Box: x_min=2000-10-13 00:00:00, y_min=418.0, x_max=2000-10-18 00:00:00, y_max=485.0
#
# Period: 271-360
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 361-450
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 451-540
# Pattern: Triple Bottom Reversal (Confidence: 0.5314)
# Bounding Box: x_min=2001-10-29 00:00:00, y_min=546.0, x_max=2001-12-27 00:00:00, y_max=606.0
#
# Period: 541-630
# Pattern: Descending Triangle (Confidence: 0.7538)
# Bounding Box: x_min=2002-04-01 00:00:00, y_min=494.0, x_max=2002-07-08 00:00:00, y_max=704.0
#
# Period: 631-720
# Pattern: Symmetrical Triangle (Confidence: 0.6670)
# Bounding Box: x_min=2002-08-27 00:00:00, y_min=510.0, x_max=2002-11-18 00:00:00, y_max=630.0
#
# Period: 721-810
# Pattern: Double Top (Confidence: 0.1266)
# Bounding Box: x_min=2002-12-27 00:00:00, y_min=591.1, x_max=2003-01-03 00:00:00, y_max=633.9
#
# Period: 811-900
# Pattern: Triple Bottom Reversal (Confidence: 0.5833)
# Bounding Box: x_min=2003-04-24 00:00:00, y_min=271.0, x_max=2003-05-08 00:00:00, y_max=297.95
#
# Period: 901-990
# Pattern: Triple Bottom Reversal (Confidence: 0.6338)
# Bounding Box: x_min=2003-08-19 00:00:00, y_min=408.45, x_max=2003-09-24 00:00:00, y_max=540.0
#
# Period: 991-1080
# Pattern: Triple Bottom Reversal (Confidence: 0.6411)
# Bounding Box: x_min=2004-01-07 00:00:00, y_min=585.05, x_max=2004-01-22 00:00:00, y_max=648.7
#
# Period: 1081-1170
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1171-1260
# Pattern: Ascending Triangle (Confidence: 0.5736)
# Bounding Box: x_min=2004-11-24 00:00:00, y_min=483.4, x_max=2005-01-05 00:00:00, y_max=575.0
#
# Period: 1261-1350
# Pattern: Triple Bottom Reversal (Confidence: 0.4469)
# Bounding Box: x_min=2005-01-27 00:00:00, y_min=374.9, x_max=2005-04-15 00:00:00, y_max=513.5
#
# Period: 1351-1440
# Pattern: Flag and Pole (Confidence: 0.6624)
# Bounding Box: x_min=2005-05-18 00:00:00, y_min=500.0, x_max=2005-09-22 00:00:00, y_max=688.0
#
# Period: 1441-1530
# Pattern: Ascending Triangle (Confidence: 0.3747)
# Bounding Box: x_min=2005-12-01 00:00:00, y_min=635.0, x_max=2006-02-02 00:00:00, y_max=750.0
#
# Period: 1531-1620
# Pattern: Double Top (Confidence: 0.7280)
# Bounding Box: x_min=2006-05-05 00:00:00, y_min=830.0, x_max=2006-05-17 00:00:00, y_max=929.4
#
# Period: 1621-1710
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1711-1800
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1801-1890
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1891-1980
# Pattern: Triple Bottom Reversal (Confidence: 0.5563)
# Bounding Box: x_min=2007-08-10 00:00:00, y_min=855.0, x_max=2007-08-29 00:00:00, y_max=975.0
#
# Period: 1981-2070
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2071-2160
# Pattern: Triple Bottom Reversal (Confidence: 0.5780)
# Bounding Box: x_min=2008-04-08 00:00:00, y_min=1234.0, x_max=2008-04-16 00:00:00, y_max=1304.8
#
# Period: 2161-2250
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2251-2340
# Pattern: Triple Bottom Reversal (Confidence: 0.4795)
# Bounding Box: x_min=2009-03-03 00:00:00, y_min=954.0, x_max=2009-03-17 00:00:00, y_max=1054.9
#
# Period: 2341-2430
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2431-2520
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2521-2610
# Pattern: Ascending Triangle (Confidence: 0.7049)
# Bounding Box: x_min=2010-03-29 00:00:00, y_min=1511.0, x_max=2010-06-17 00:00:00, y_max=1853.0
#
# Period: 2611-2700
# Pattern: Triple Bottom Reversal (Confidence: 0.4946)
# Bounding Box: x_min=2010-08-17 00:00:00, y_min=1700.05, x_max=2010-09-07 00:00:00, y_max=1857.0
#
# Period: 2701-2790
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2791-2880
# Pattern: Symmetrical Triangle (Confidence: 0.7349)
# Bounding Box: x_min=2011-06-16 00:00:00, y_min=471.85, x_max=2011-07-12 00:00:00, y_max=512.5
#
# Period: 2881-2970
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2971-3060
# Pattern: Ascending Triangle (Confidence: 0.5479)
# Bounding Box: x_min=2012-03-03 00:00:00, y_min=535.9, x_max=2012-04-02 00:00:00, y_max=594.0
#
# Period: 3061-3150
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3151-3240
# Pattern: Triple Bottom Reversal (Confidence: 0.5733)
# Bounding Box: x_min=2012-08-24 00:00:00, y_min=641.35, x_max=2012-09-21 00:00:00, y_max=695.5
#
# Period: 3241-3330
# Pattern: Triple Bottom Reversal (Confidence: 0.7890)
# Bounding Box: x_min=2013-01-23 00:00:00, y_min=700.0, x_max=2013-02-04 00:00:00, y_max=732.85
#
# Period: 3331-3420
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2013-07-22 00:00:00, y_min=1068.0, x_max=2013-07-26 00:00:00, y_max=1131.0
#
# Period: 3421-3510
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3511-3600
# Pattern: Double Top (Confidence: 0.3411)
# Bounding Box: x_min=2014-04-29 00:00:00, y_min=620.2, x_max=2014-05-07 00:00:00, y_max=643.95
#
# Period: 3601-3690
# Pattern: Ascending Triangle (Confidence: 0.3502)
# Bounding Box: x_min=2014-08-26 00:00:00, y_min=748.0, x_max=2014-10-16 00:00:00, y_max=878.4
#
# Period: 3691-3780
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3781-3870
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3871-3960
# Pattern: Symmetrical Triangle (Confidence: 0.2789)
# Bounding Box: x_min=2015-07-20 00:00:00, y_min=724.05, x_max=2015-11-19 00:00:00, y_max=966.0
#
# Period: 3961-4050
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4051-4140
# Pattern: Triple Bottom Reversal (Confidence: 0.5610)
# Bounding Box: x_min=2016-06-10 00:00:00, y_min=733.15, x_max=2016-06-21 00:00:00, y_max=758.35
#
# Period: 4141-4230
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4231-4320
# Pattern: Double Top (Confidence: 0.6823)
# Bounding Box: x_min=2017-03-24 00:00:00, y_min=689.5, x_max=2017-03-28 00:00:00, y_max=709.65
#
# Period: 4321-4410
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4411-4500
# Pattern: Cup and Handle (Confidence: 0.1000)
# Bounding Box: x_min=2017-10-03 00:00:00, y_min=498.2, x_max=2018-01-23 00:00:00, y_max=604.6
#
# Period: 4501-4590
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4591-4680
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4681-4770
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4771-4860
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4861-4950
# Pattern: Triple Bottom Reversal (Confidence: 0.1639)
# Bounding Box: x_min=2019-10-07 00:00:00, y_min=372.6, x_max=2019-10-23 00:00:00, y_max=411.35
#
# Period: 4951-5040
# Pattern: Symmetrical Triangle (Confidence: 0.2396)
# Bounding Box: x_min=2019-11-27 00:00:00, y_min=312.0, x_max=2020-04-03 00:00:00, y_max=462.5
#
# Period: 5041-5130
# Pattern: Triple Bottom Reversal (Confidence: 0.6993)
# Bounding Box: x_min=2020-05-07 00:00:00, y_min=434.25, x_max=2020-05-27 00:00:00, y_max=475.55
#
# Period: 5131-5220
# Pattern: Inverse Head and Shoulders (Confidence: 0.8229)
# Bounding Box: x_min=2020-10-19 00:00:00, y_min=452.25, x_max=2020-11-10 00:00:00, y_max=518.25
#
#
# === Processing file: ZEEL.csv ===
#
# Processing segment: 1-90
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 848.94
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -15.400000, Min slope: -41.945000, max_r²: 0.4785, min_r²: 0.5493
# Breakout check: 1156.28 < Close 523.40 < 1927.12
# No breakout
#
# Processing segment: 91-180
# Failed shoulder-head condition
# Handle max invalid: Exists: True, Days: 34 < 5, Value: 546.4 > 478.62
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -18.985000, Min slope: -9.480000, max_r²: 0.5024, min_r²: 0.7158
# Breakout check: 482.59 < Close 468.75 < 804.31
# No breakout
#
# Processing segment: 181-270
# Failed shoulder-head condition
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 310.26
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -16.855000, Min slope: -7.450000, max_r²: 0.4919, min_r²: 0.6268
# Breakout check: 338.70 < Close 266.00 < 564.50
# No breakout
#
# Processing segment: 271-360
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2474
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 127.68
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -6.705000, Min slope: 3.565000, max_r²: 0.7891, min_r²: 0.2053
# Slopes not steep enough or weak fit: Max slope -6.705000 > -0.0012, Min slope 3.565000 > -0.0012, max_r² 0.7891 <= 0.25, min_r² 0.2053 <= 0.25
#
# Processing segment: 361-450
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.4498 < 0.2 or min_r² 0.0035 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 103.32
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.220000, Min slope: 0.555000, max_r²: 0.3008, min_r²: 0.0136
# Slopes not steep enough or weak fit: Max slope -1.220000 > -0.0012, Min slope 0.555000 > -0.0012, max_r² 0.3008 <= 0.25, min_r² 0.0136 <= 0.25
#
# Processing segment: 451-540
# Detected Symmetrical Triangle with confidence 0.3736
# Close: 152.95, Neckline: 146.85, Threshold: 147.29
# Trend: bullish, RSI: 62.84
# Detected Cup and Handle with confidence 0.6275
# Detected Cup and Handle with confidence 0.6275
# Detected Ascending Triangle with confidence 0.7385
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 3.885000, Min slope: 3.910000, max_r²: 0.6837, min_r²: 0.9231
# Slopes not steep enough or weak fit: Max slope 3.885000 > -0.0012, Min slope 3.910000 > -0.0012, max_r² 0.6837 <= 0.25, min_r² 0.9231 <= 0.25
#
# Processing segment: 541-630
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2831 < 0.2 or min_r² 0.1846 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 154.14
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.060000, Min slope: 1.240000, max_r²: 0.3162, min_r²: 0.3004
# Slopes not steep enough or weak fit: Max slope 2.060000 > -0.0012, Min slope 1.240000 > -0.0012, max_r² 0.3162 <= 0.25, min_r² 0.3004 <= 0.25
#
# Processing segment: 631-720
# Failed shoulder-head condition
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 100.38
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.690000, Min slope: -0.515000, max_r²: 0.8620, min_r²: 0.8659
# Slope ratio too large: 5.2233 >= 4.0
#
# Processing segment: 721-810
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1432 < 0.2 or min_r² 0.8116 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 89.16
# Detected Descending Triangle with confidence 0.1885
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.430000, Min slope: -2.370000, max_r²: 0.2356, min_r²: 0.7067
# Slopes not steep enough or weak fit: Max slope -0.430000 > -0.0012, Min slope -2.370000 > -0.0012, max_r² 0.2356 <= 0.25, min_r² 0.7067 <= 0.25
# Detected Double Top with confidence 0.6458
#
# Processing segment: 811-900
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.7881 < 0.2 or min_r² 0.0337 < 0.2
# Handle max invalid: Exists: True, Days: 98 < 5, Value: 121.35 > 83.64
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.250000, Min slope: 0.605000, max_r²: 0.7778, min_r²: 0.0657
# Slopes not steep enough or weak fit: Max slope 1.250000 > -0.0012, Min slope 0.605000 > -0.0012, max_r² 0.7778 <= 0.25, min_r² 0.0657 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.3459
#
# Processing segment: 901-990
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0652 < 0.2 or min_r² 0.3731 < 0.2
# Handle max invalid: Exists: True, Days: 82 < 5, Value: 142.3 > 124.62
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.540000, Min slope: -0.875000, max_r²: 0.1670, min_r²: 0.2712
# Slopes not steep enough or weak fit: Max slope -0.540000 > -0.0012, Min slope -0.875000 > -0.0012, max_r² 0.1670 <= 0.25, min_r² 0.2712 <= 0.25
#
# Processing segment: 991-1080
# Trendlines too weak: max_r² 0.0128 < 0.2 or min_r² 0.4567 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 144.60
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.160000, Min slope: -0.935000, max_r²: 0.0045, min_r²: 0.1229
# Slopes not steep enough or weak fit: Max slope -0.160000 > -0.0012, Min slope -0.935000 > -0.0012, max_r² 0.0045 <= 0.25, min_r² 0.1229 <= 0.25
#
# Processing segment: 1081-1170
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4255
# Close: 151.40, Neckline: 127.75, Threshold: 128.13
# Trend: bullish, RSI: 82.80
# Detected Cup and Handle with confidence 0.3939
# Detected Ascending Triangle with confidence 0.6356
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 2.055000, Min slope: 2.800000, max_r²: 0.6613, min_r²: 0.7945
# Slopes not steep enough or weak fit: Max slope 2.055000 > -0.0012, Min slope 2.800000 > -0.0012, max_r² 0.6613 <= 0.25, min_r² 0.7945 <= 0.25
#
# Processing segment: 1171-1260
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2249 < 0.2 or min_r² 0.1077 < 0.2
# Close: 170.05, Neckline: 160.40, Threshold: 160.88
# Trend: bullish, RSI: 45.91
# Detected Cup and Handle with confidence 0.1749
# Detected Cup and Handle with confidence 0.1749
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.040000, Min slope: 0.445000, max_r²: 0.3052, min_r²: 0.0770
# Slopes not steep enough or weak fit: Max slope -1.040000 > -0.0012, Min slope 0.445000 > -0.0012, max_r² 0.3052 <= 0.25, min_r² 0.0770 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.1967
#
# Processing segment: 1261-1350
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2339 < 0.2 or min_r² 0.1740 < 0.2
# Close: 151.30, Neckline: 132.05, Threshold: 132.45
# Trend: bullish, RSI: 72.87
# Detected Cup and Handle with confidence 0.6713
# Detected Cup and Handle with confidence 0.6713
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.205000, Min slope: -0.220000, max_r²: 0.7595, min_r²: 0.0886
# Slopes not steep enough or weak fit: Max slope -3.205000 > -0.0012, Min slope -0.220000 > -0.0012, max_r² 0.7595 <= 0.25, min_r² 0.0886 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.7552
#
# Processing segment: 1351-1440
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1707 < 0.2 or min_r² 0.0075 < 0.2
# Handle max invalid: Exists: True, Days: 87 < 5, Value: 198.45 > 176.40
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.085000, Min slope: -0.645000, max_r²: 0.1200, min_r²: 0.0478
# Slopes not steep enough or weak fit: Max slope 1.085000 > -0.0012, Min slope -0.645000 > -0.0012, max_r² 0.1200 <= 0.25, min_r² 0.0478 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.1522
#
# Processing segment: 1441-1530
# Failed shoulder-head condition
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 197.94
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -5.230000, Min slope: 2.925000, max_r²: 0.7886, min_r²: 0.8657
# Slopes not steep enough or weak fit: Max slope -5.230000 > -0.0012, Min slope 2.925000 > -0.0012, max_r² 0.7886 <= 0.25, min_r² 0.8657 <= 0.25
#
# ...
# Handle max invalid: Exists: True, Days: 99 < 5, Value: 407.95 > 339.72
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 23.345000, Min slope: -0.780000, max_r²: 0.8817, min_r²: 0.1350
# Slopes not steep enough or weak fit: Max slope 23.345000 > -0.0012, Min slope -0.780000 > -0.0012, max_r² 0.8817 <= 0.25, min_r² 0.1350 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.4566
#
# Processing segment: 3601-3690
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0338 < 0.2 or min_r² 0.3080 < 0.2
# Close: 397.10, Neckline: 405.25, Threshold: 406.47
# Breakout not confirmed
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -2.155000, Min slope: -1.580000, max_r²: 0.1247, min_r²: 0.3554
# Slopes not steep enough or weak fit: Max slope -2.155000 > -0.0012, Min slope -1.580000 > -0.0012, max_r² 0.1247 <= 0.25, min_r² 0.3554 <= 0.25
# Detected Double Top with confidence 0.3084
#
# Processing segment: 3691-3780
# Detected Head and Shoulders with confidence 0.8890
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 400.14
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -3.890000, Min slope: -4.705000, max_r²: 0.5443, min_r²: 0.6939
# Breakout check: 314.25 < Close 324.75 < 523.75
# Trend: bearish, RSI: 29.12
# Trend not bullish or RSI too low: Trend bearish, RSI 29.12 <= 30
#
# Processing segment: 3781-3870
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.0639 < 0.2 or min_r² 0.4814 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 382.98
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.045000, Min slope: -0.675000, max_r²: 0.0949, min_r²: 0.7742
# Slopes not steep enough or weak fit: Max slope -1.045000 > -0.0012, Min slope -0.675000 > -0.0012, max_r² 0.0949 <= 0.25, min_r² 0.7742 <= 0.25
#
# Processing segment: 3871-3960
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.7054 < 0.2 or min_r² 0.0144 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 287.04
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -4.125000, Min slope: 0.220000, max_r²: 0.6264, min_r²: 0.1838
# Slopes not steep enough or weak fit: Max slope -4.125000 > -0.0012, Min slope 0.220000 > -0.0012, max_r² 0.6264 <= 0.25, min_r² 0.1838 <= 0.25
#
# Processing segment: 3961-4050
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 249.90
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.905000, Min slope: 3.165000, max_r²: 0.8287, min_r²: 0.5464
# Slopes not steep enough or weak fit: Max slope 1.905000 > -0.0012, Min slope 3.165000 > -0.0012, max_r² 0.8287 <= 0.25, min_r² 0.5464 <= 0.25
#
# Processing segment: 4051-4140
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.2467 < 0.2 or min_r² 0.0596 < 0.2
# Close: 231.40, Neckline: 214.25, Threshold: 214.89
# Trend: bullish, RSI: 65.09
# Detected Cup and Handle with confidence 0.1000
# Detected Cup and Handle with confidence 0.1000
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.185000, Min slope: -0.125000, max_r²: 0.0031, min_r²: 0.0159
# Slopes not steep enough or weak fit: Max slope 0.185000 > -0.0012, Min slope -0.125000 > -0.0012, max_r² 0.0031 <= 0.25, min_r² 0.0159 <= 0.25
#
# Processing segment: 4141-4230
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.4103
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 241.80
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 4.725000, Min slope: -12.715000, max_r²: 0.7169, min_r²: 0.8019
# Slopes not steep enough or weak fit: Max slope 4.725000 > -0.0012, Min slope -12.715000 > -0.0012, max_r² 0.7169 <= 0.25, min_r² 0.8019 <= 0.25
#
# Processing segment: 4231-4320
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0002 < 0.2 or min_r² 0.2007 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 230.88
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.195000, Min slope: -0.750000, max_r²: 0.0396, min_r²: 0.1340
# Slopes not steep enough or weak fit: Max slope -0.195000 > -0.0012, Min slope -0.750000 > -0.0012, max_r² 0.0396 <= 0.25, min_r² 0.1340 <= 0.25
#
# Processing segment: 4321-4410
# Failed shoulder-head condition
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 190.08
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -4.280000, Min slope: -0.235000, max_r²: 0.9561, min_r²: 0.7126
# Slope ratio too large: 18.2128 >= 4.0
#
# Processing segment: 4411-4500
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.1250 < 0.2 or min_r² 0.5490 < 0.2
# Handle max invalid: Exists: True, Days: 102 < 5, Value: 207.35 > 203.64
# Detected Ascending Triangle with confidence 0.5109
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.390000, Min slope: 1.360000, max_r²: 0.3222, min_r²: 0.6386
# Slopes not steep enough or weak fit: Max slope 1.390000 > -0.0012, Min slope 1.360000 > -0.0012, max_r² 0.3222 <= 0.25, min_r² 0.6386 <= 0.25
#
# Processing segment: 4501-4590
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2838
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 213.48
# Detected Descending Triangle with confidence 0.3974
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -4.085000, Min slope: -0.740000, max_r²: 0.4967, min_r²: 0.1433
# Slopes not steep enough or weak fit: Max slope -4.085000 > -0.0012, Min slope -0.740000 > -0.0012, max_r² 0.4967 <= 0.25, min_r² 0.1433 <= 0.25
#
# Processing segment: 4591-4680
# Detected Head and Shoulders with confidence 0.8851
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 179.76
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 1.305000, Min slope: -2.210000, max_r²: 0.3634, min_r²: 0.7183
# Slopes not steep enough or weak fit: Max slope 1.305000 > -0.0012, Min slope -2.210000 > -0.0012, max_r² 0.3634 <= 0.25, min_r² 0.7183 <= 0.25
#
# Processing segment: 4681-4770
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.4403 < 0.2 or min_r² 0.1349 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 177.48
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 0.860000, Min slope: -1.370000, max_r²: 0.3833, min_r²: 0.3309
# Slopes not steep enough or weak fit: Max slope 0.860000 > -0.0012, Min slope -1.370000 > -0.0012, max_r² 0.3833 <= 0.25, min_r² 0.3309 <= 0.25
#
# Processing segment: 4771-4860
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 212.40
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.940000, Min slope: 0.875000, max_r²: 0.6512, min_r²: 0.7794
# Slopes not steep enough or weak fit: Max slope -0.940000 > -0.0012, Min slope 0.875000 > -0.0012, max_r² 0.6512 <= 0.25, min_r² 0.7794 <= 0.25
#
# Processing segment: 4861-4950
# Failed shoulder-head condition
# Trendlines too weak: max_r² 0.0962 < 0.2 or min_r² 0.7268 < 0.2
# Close: 130.25, Neckline: 137.05, Threshold: 137.46
# Breakout not confirmed
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.210000, Min slope: 2.020000, max_r²: 0.3235, min_r²: 0.6539
# Slopes not steep enough or weak fit: Max slope -1.210000 > -0.0012, Min slope 2.020000 > -0.0012, max_r² 0.3235 <= 0.25, min_r² 0.6539 <= 0.25
#
# Processing segment: 4951-5040
# Detected Head and Shoulders with confidence 0.9000
# Trendlines too weak: max_r² 0.7833 < 0.2 or min_r² 0.1464 < 0.2
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 75.00
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -1.065000, Min slope: -0.150000, max_r²: 0.7061, min_r²: 0.0582
# Slopes not steep enough or weak fit: Max slope -1.065000 > -0.0012, Min slope -0.150000 > -0.0012, max_r² 0.7061 <= 0.25, min_r² 0.0582 <= 0.25
#
# Processing segment: 5041-5130
# Detected Head and Shoulders with confidence 0.9000
# Handle max invalid: Exists: False, Days: N/A < 5, Value: N/A > 109.14
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: -0.650000, Min slope: 1.065000, max_r²: 0.1601, min_r²: 0.1505
# Slopes not steep enough or weak fit: Max slope -0.650000 > -0.0012, Min slope 1.065000 > -0.0012, max_r² 0.1601 <= 0.25, min_r² 0.1505 <= 0.25
#
# Processing segment: 5131-5220
# Failed shoulder-head condition
# Detected Symmetrical Triangle with confidence 0.2091
# Handle max invalid: Exists: True, Days: 48 < 5, Value: 102.9 > 82.80
# Falling Wedge - Maxima count: 5, Minima count: 5
# Max slope: 6.105000, Min slope: -0.555000, max_r²: 0.9151, min_r²: 0.3346
# Slopes not steep enough or weak fit: Max slope 6.105000 > -0.0012, Min slope -0.555000 > -0.0012, max_r² 0.9151 <= 0.25, min_r² 0.3346 <= 0.25
# Detected Triple Bottom Reversal with confidence 0.6038
# Detected patterns in 34/58 segments (58.6%)
# Period: 1-90
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 91-180
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 181-270
# Pattern: Triple Bottom Reversal (Confidence: 0.6154)
# Bounding Box: x_min=2000-10-17 00:00:00, y_min=98.15, x_max=2000-10-30 00:00:00, y_max=107.95
#
# Period: 271-360
# Pattern: Triple Bottom Reversal (Confidence: 0.5958)
# Bounding Box: x_min=2001-03-26 00:00:00, y_min=121.0, x_max=2001-04-06 00:00:00, y_max=138.0
#
# Period: 361-450
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 451-540
# Pattern: Triple Bottom Reversal (Confidence: 0.7556)
# Bounding Box: x_min=2001-12-20 00:00:00, y_min=129.2, x_max=2002-01-25 00:00:00, y_max=155.9
#
# Period: 541-630
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2002-05-10 00:00:00, y_min=326.55, x_max=2002-05-22 00:00:00, y_max=398.95
#
# Period: 631-720
# Pattern: Ascending Triangle (Confidence: 0.4144)
# Bounding Box: x_min=2002-10-11 00:00:00, y_min=350.0, x_max=2002-11-18 00:00:00, y_max=410.0
#
# Period: 721-810
# Pattern: Symmetrical Triangle (Confidence: 0.4398)
# Bounding Box: x_min=2003-01-09 00:00:00, y_min=333.0, x_max=2003-03-28 00:00:00, y_max=390.45
#
# Period: 811-900
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 901-990
# Pattern: Ascending Triangle (Confidence: 0.1721)
# Bounding Box: x_min=2003-09-02 00:00:00, y_min=512.1, x_max=2003-12-11 00:00:00, y_max=695.0
#
# Period: 991-1080
# Pattern: Triple Bottom Reversal (Confidence: 0.2017)
# Bounding Box: x_min=2004-02-05 00:00:00, y_min=665.0, x_max=2004-02-25 00:00:00, y_max=786.7
#
# Period: 1081-1170
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1171-1260
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1261-1350
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1351-1440
# Pattern: Ascending Triangle (Confidence: 0.5872)
# Bounding Box: x_min=2005-06-30 00:00:00, y_min=890.0, x_max=2005-09-22 00:00:00, y_max=1082.0
#
# Period: 1441-1530
# Pattern: Triple Bottom Reversal (Confidence: 0.2493)
# Bounding Box: x_min=2005-10-28 00:00:00, y_min=909.0, x_max=2005-11-09 00:00:00, y_max=978.7
#
# Period: 1531-1620
# Pattern: Head and Shoulders (Confidence: 0.8623)
# Bounding Box: x_min=2006-04-26 00:00:00, y_min=1250.0, x_max=2006-05-17 00:00:00, y_max=1513.9
#
# Period: 1621-1710
# Pattern: Double Top (Confidence: 0.1574)
# Bounding Box: x_min=2006-08-29 00:00:00, y_min=1200.0, x_max=2006-09-05 00:00:00, y_max=1239.1
#
# Period: 1711-1800
# Pattern: Descending Triangle (Confidence: 0.6045)
# Bounding Box: x_min=2006-10-21 00:00:00, y_min=726.5, x_max=2007-03-05 00:00:00, y_max=1170.0
#
# Period: 1801-1890
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 1891-1980
# Pattern: Ascending Triangle (Confidence: 0.6267)
# Bounding Box: x_min=2007-10-29 00:00:00, y_min=1156.55, x_max=2007-11-20 00:00:00, y_max=1385.05
#
# Period: 1981-2070
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2071-2160
# Pattern: Triple Bottom Reversal (Confidence: 0.6540)
# Bounding Box: x_min=2008-07-01 00:00:00, y_min=778.7, x_max=2008-07-15 00:00:00, y_max=927.25
#
# Period: 2161-2250
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2251-2340
# Pattern: Ascending Triangle (Confidence: 0.2984)
# Bounding Box: x_min=2009-04-08 00:00:00, y_min=802.35, x_max=2009-05-18 00:00:00, y_max=975.8
#
# Period: 2341-2430
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2431-2520
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2010-01-11 00:00:00, y_min=1180.0, x_max=2010-01-18 00:00:00, y_max=1246.75
#
# Period: 2521-2610
# Pattern: Symmetrical Triangle (Confidence: 0.5545)
# Bounding Box: x_min=2010-05-20 00:00:00, y_min=1034.0, x_max=2010-06-17 00:00:00, y_max=1230.0
#
# Period: 2611-2700
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2701-2790
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2791-2880
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2881-2970
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 2971-3060
# Pattern: Double Top (Confidence: 0.5722)
# Bounding Box: x_min=2012-03-05 00:00:00, y_min=276.5, x_max=2012-03-14 00:00:00, y_max=295.0
#
# Period: 3061-3150
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3151-3240
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3241-3330
# Pattern: Ascending Triangle (Confidence: 0.7381)
# Bounding Box: x_min=2013-01-18 00:00:00, y_min=289.25, x_max=2013-05-03 00:00:00, y_max=355.0
#
# Period: 3331-3420
# Pattern: Head and Shoulders (Confidence: 0.6920)
# Bounding Box: x_min=2013-05-22 00:00:00, y_min=296.1, x_max=2013-06-28 00:00:00, y_max=353.05
#
# Period: 3421-3510
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3511-3600
# Pattern: Triple Bottom Reversal (Confidence: 0.4566)
# Bounding Box: x_min=2014-02-03 00:00:00, y_min=264.15, x_max=2014-02-13 00:00:00, y_max=284.0
#
# Period: 3601-3690
# Pattern: Double Top (Confidence: 0.3084)
# Bounding Box: x_min=2014-09-02 00:00:00, y_min=431.1, x_max=2014-09-08 00:00:00, y_max=456.5
#
# Period: 3691-3780
# Pattern: Head and Shoulders (Confidence: 0.8890)
# Bounding Box: x_min=2014-10-31 00:00:00, y_min=382.5, x_max=2014-11-17 00:00:00, y_max=412.5
#
# Period: 3781-3870
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2015-05-25 00:00:00, y_min=313.2, x_max=2015-05-29 00:00:00, y_max=337.2
#
# Period: 3871-3960
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 3961-4050
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4051-4140
# Pattern: Cup and Handle (Confidence: 0.1000)
# Bounding Box: x_min=2016-05-16 00:00:00, y_min=200.0, x_max=2016-08-11 00:00:00, y_max=241.55
#
# Period: 4141-4230
# Pattern: Symmetrical Triangle (Confidence: 0.4103)
# Bounding Box: x_min=2016-10-24 00:00:00, y_min=192.5, x_max=2016-12-23 00:00:00, y_max=314.6
#
# Period: 4231-4320
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4321-4410
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4411-4500
# Pattern: Ascending Triangle (Confidence: 0.5109)
# Bounding Box: x_min=2017-11-06 00:00:00, y_min=175.35, x_max=2018-01-23 00:00:00, y_max=208.7
#
# Period: 4501-4590
# Pattern: Descending Triangle (Confidence: 0.3974)
# Bounding Box: x_min=2018-01-24 00:00:00, y_min=155.15, x_max=2018-06-06 00:00:00, y_max=212.85
#
# Period: 4591-4680
# Pattern: Head and Shoulders (Confidence: 0.8851)
# Bounding Box: x_min=2018-09-06 00:00:00, y_min=166.2, x_max=2018-10-03 00:00:00, y_max=185.4
#
# Period: 4681-4770
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4771-4860
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2019-05-24 00:00:00, y_min=166.55, x_max=2019-06-03 00:00:00, y_max=176.4
#
# Period: 4861-4950
# Pattern: No Pattern Detected (Confidence: 0.0000)
#
# Period: 4951-5040
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2019-12-27 00:00:00, y_min=126.85, x_max=2020-01-03 00:00:00, y_max=133.4
#
# Period: 5041-5130
# Pattern: Head and Shoulders (Confidence: 0.9000)
# Bounding Box: x_min=2020-06-17 00:00:00, y_min=81.8, x_max=2020-06-23 00:00:00, y_max=86.5
#
# Period: 5131-5220
# Pattern: Triple Bottom Reversal (Confidence: 0.6038)
# Bounding Box: x_min=2020-10-15 00:00:00, y_min=64.1, x_max=2020-10-29 00:00:00, y_max=70.45
#
#
# === Overall Summary ===
# Total files processed: 52
# Detected patterns in 1535/2577 segments across all files (59.6%)
# Saved labels to /content/drive/MyDrive/nifty50_labels.csv
